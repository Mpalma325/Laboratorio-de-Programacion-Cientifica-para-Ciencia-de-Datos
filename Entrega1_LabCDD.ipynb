# %% [markdown]
# ![](https://www.dii.uchile.cl/wp-content/uploads/2021/06/Magi%CC%81ster-en-Ciencia-de-Datos.png)

# %% [markdown]
# **MDS7202: Laboratorio de Programación Científica para Ciencia de Datos**
#
# ### 👨‍🏫👩‍🏫 Cuerpo Docente:
#
# - Profesores: Diego Cortez, Gabriel Iturra
# - Auxiliares: Melanie Peña, Valentina Rojas
# - Ayudantes: Nicolás Cabello, Cristopher Urbina
#
# ### 👨‍💻👩‍💻 Estudiantes:
# - Estudiante n°1: Isaac Torrejón O.
# - Estudiante n°2: Marcelo Iván Palma M.
#
# _Por favor, lean detalladamente las instrucciones de la tarea antes de empezar a escribir._
#
# ---

# %% [markdown]
# ---
#
# ## 📖 Enunciado

# %% [markdown]
# <div align="center">
#     <img src='https://github.com/MDS7202/MDS7202/blob/main/recursos/2025-01/proyecto/proyecto.png?raw=true' style="border-radius: 12px">
# </div>

# %% [markdown]
# En el competitivo universo de las bebidas gaseosas, la empresa **SodAI Drinks 🥤** ha logrado destacarse por su creatividad, diversidad de productos y enfoque centrado en el cliente. Ofrece una extensa gama de bebidas carbonatadas que abarca distintos segmentos del mercado: desde productos premium en presentaciones sofisticadas, hasta gaseosas accesibles para el consumo masivo, disponibles en diversos tamaños y tipos de envases.
#
# La compañía opera en múltiples regiones y zonas, sirviendo a una variedad de puntos de venta que incluyen desde tiendas de conveniencia y minimarkets hasta el canal frío tradicional. Cada tipo de cliente tiene sus particularidades: algunos reciben entregas hasta 4 veces por semana, mientras que otros son visitados por la fuerza de ventas solo una vez semanalmente. Esta diversidad de perfiles representa tanto una oportunidad como un desafío comercial: ¿cómo saber qué productos tienen más chances de ser comprados por cada cliente en un momento dado?
#
# Con el objetivo de aumentar la facturación de forma inteligente y mejorar la eficiencia de su estrategia de ventas, **SodAI Drinks** decide crear una nueva célula interna de innovación: el equipo **Deep Drinkers 🤖**, cuyo propósito es aplicar ciencia de datos para anticiparse a las necesidades del cliente y potenciar el negocio desde una perspectiva basada en información.
#
# El corazón de esta iniciativa es el desarrollo de un sistema predictivo personalizado para cada cliente. Para ello, **Deep Drinkers** convoca a un equipo de Data Scientists y especialistas en *machine learning* con una misión clara: construir un modelo predictivo que, cada semana, pueda estimar la probabilidad de compra de cada producto del portafolio para cada cliente activo.
#
# El modelo deberá tener en cuenta múltiples factores, incluyendo:
# - **Tipo de cliente**, ej. "TIENDA DE CONVENIENCIA", "MINIMARKET".
# - **Frecuencia de entregas y visitas**, indicadores del nivel de actividad comercial.
# - **Ubicación geográfica** (por región y zona).
# - **Preferencias históricas de consumo**, inferidas por patrones de compra anteriores.
# - **Características del producto**, como marca, categoría, segmento, tipo de envase y tamaño
#
# El objetivo final es que, **cada semana**, se genere una tabla de productos priorizados: para cada cliente, un listado de productos ordenado por su probabilidad estimada de compra. Esta información será enviada al equipo comercial, que podrá usarla en call center, para incrementar las chances de concretar ventas al ofrecer justo lo que el cliente probablemente quiere comprar.
#
# Este proyecto representa un cambio de paradigma en la forma en que **SodAI Drinks** gestiona su fuerza de ventas: de un enfoque reactivo y generalista, a uno proactivo, basado en datos y profundamente personalizado. Así, la empresa no solo espera aumentar su rentabilidad, sino también construir relaciones más sólidas con sus clientes, ofreciéndoles recomendaciones más relevantes y oportunas.
#
# Para lograr lo anterior, el equipo **Deep Drinkers** contará con los siguientes conjuntos de datos, junto a sus respectivos atributos:
#
# - **Datos transaccionales** (`transacciones.parquet`): contiene el historial de compras realizadas por los clientes.
# 	- `customer_id`: identificador único del cliente que realizó la compra.
# 	- `product_id`: identificador único del producto comprado.
# 	- `purchase_date`: fecha en que se realizó la transacción.
# 	- `order_id`: identificar de la orden de su pedido.
# 	- `payment`	monto total pagado por la transacción.
#
# - **Datos de clientes** (`clientes.parquet`): incluye las características de cada cliente.
# 	- `customer_id`: identificador único del cliente.
# 	- `region_id`: identificador de la región geográfica donde se encuentra el cliente.
# 	- `customer_type`: tipo de cliente según el canal comercial, por ejemplo, “TIENDA DE CONVENIENCIA”.
# 	- `Y`: coordenada geográfica de latitud.
# 	- `X`: coordenada geográfica de longitud.
# 	- `num_deliver_per_week`: cantidad de entregas semanales que recibe el cliente.
# 	- `num_visit_per_week`: frecuencia de visitas de la fuerza de ventas por semana.
#
# - **Datos de productos** (`productos.parquet`): describe las características de los productos del portafolio.
# 	- `product_id`: identificador único del producto.
# 	- `brand`: marca comercial del producto.
# 	- `category`: categoría general del producto, como “BEBIDAS CARBONATADAS”.
# 	- `sub_category`: subcategoría dentro de la categoría principal, por ejemplo, “GASEOSAS”.
# 	- `segment`: segmento de mercado al que pertenece el producto, como “PREMIUM”.
# 	- `package`: tipo de envase del producto.
# 	- `size`: tamaño del producto en litros.

# %% [markdown]
# <center>
# <img src="https://media1.tenor.com/m/0Qtv_cQ4ITsAAAAd/necohaus-grey-name.gif" width="450">

# %% [markdown]
# El proyecto consta de **dos entregas parciales** y una **entrega final** en donde la primera entrega la idea es poder reflejar lo aprendido durante la primera mitad del curso, que será sobre los contenidos relacionados a *machine learning*, la segunda será sobre los contenidos de la segunda mitad del curso relacionados a *MLOps* y por último la entrega final constará de dos partes, donde la primera será relacionada con experimentación sobre nuevos datasets que serán disponibilizados durante las últimas semanas del curso de manera incremental y una segunda parte que será el informe final escrito que deberá explicar el desarrollo del proyecto completo, como tambien los resultados y análisis de los experimentos realizados sobre los datasets incrementales. La idea es que todo el código esté desarrollado durante las primeras dos entregas y luego en la entrega final sólo se ejecute el código sobre nuevos conjuntos de datos.
#
# La idea de generar el proyecto por etapas es poder aliviar la carga de trabajo en las últimas semanas del semestre donde sabemos que están muy cargado con entregas, pruebas y exámenes de otros ramos, y así garantizamos que habiendo la desarrollado las dos primeras entregas parciales, tendrán el grueso del proyecto listo para luego experimentar y documentar.
#
# ---
# ### **Fechas de entrega**
# - **Entrega parcial 1**: 12 de Septiembre
# - **Entrega parcial 2**: Por definir
# - **Entrega final**: Por definir
#
# ---
#
# ### **Requisitos del proyecto**
# - **Grupos**: Formar equipos de **2 personas**. No se aceptarán trabajos individuales o grupos con más integrantes.
# - **Consultas**: Cualquier duda fuera del horario de clases debe ser planteada en el foro correspondiente. Los mensajes enviados al equipo docente serán respondidos únicamente por este medio. Por favor, revisen las respuestas anteriores en el foro antes de realizar nuevas consultas.
# - **Plagio**: La copia o reutilización no autorizada de trabajos de otros grupos está **estrictamente prohibida**. El incumplimiento de esta norma implicará la anulación inmediata del proyecto y una posible sanción académica.
# - **Material permitido**: Pueden usar cualquier material del curso, ya sea notas, lecturas, códigos, o referencias proporcionadas por los docentes, que consideren útil para el desarrollo del proyecto.
#
# ---
#
# ### **Entregables y etapas**
#
# #### **1. Entrega Parcial 1**
# - Dispondrán de los archivos de datos **productos.parquet**, **clientes.parquet** y **transacciones.parquet** para el modelamiento inicial.
# - Utilizarán estos archivos para desarrollar lo solicitado para la entrega 1.
# - En esta etapa, se espera que apliquen todos los conocimientos aprendidos durante la primera parte del curso relacionados con *machine learning*.
# - **Informe**: No se exige un avance del informe en esta etapa, sólo un notebook con su desarrollo actual, pero se **recomienda comenzar** a redactar el informe final en paralelo para disminuir la carga académica en las etapas posteriores.
#
# #### **2. Entrega Parcial 2**
# - En esta entrega, deberán aplicar los conocimientos aprendidos durante la segunda mitad del curso sobre *MLOps*
# - Se espera que implementen estos conocimientos para desplegar su modelo elegido en la primera entrega y crear *pipelines* automatizados que simulen un entorno productivo.
# - **Informe**: similar a la primera etapa, no se exige un avance del informe, pero se **recomienda avanzar con su redacción** para evitar una acumulación de trabajo en la etapa final.
#
# #### **3. Entrega Final**
# - En la entrega final, deberán realizar dos etapas:
# 	- La primera etapa es sobre experimentación utilizando datasets incrementales que se irán disponibilizando de manera parcial, para que vayan generando predicciones con su modelo ya desplegado. El objetivo de esta etapa es poder testear su solución *end-to-end* y que vayan analizando los resultados obtenidos a medida que se van agregando más datos.
# 	- La segunda etapa consiste en redactar un informe final que deberá explicar el desarrollo completo de tu proyecto y un análisis profundo de sus resultados de experimentación. Este informe debera incluir a lo menos las siguientes secciones:
# 		- Análisis exploratorio de datos
# 		- Metodología aplicada
# 		- Selección y entrenamiento de modelos
# 		- Evaluación de resultados
# 		- Optimización de modelos
# 		- Interpretabilidad
# 		- Re-entrenamiento
# 		- Tracking con MLFlow
# 		- Creación de la aplicación web con Gradio y FastAPI
#
# Es **altamente recomendable** ir redactando el informe en paralelo al desarrollo de los modelos para garantizar que toda la información relevante quede documentada adecuadamente.
#
# ### Nota Final
#
# La calificación final de su proyecto se calculará utilizando la siguiente ponderación:
#
# $$Nota Final = 0.30 * EntregaParcial1 + 0.40 * EntregaParcial2 + 0.30 * EntregaFinal$$
#
# ---
#
# ### **Instrucciones importantes**
#
# 1. **Formato del informe**:
#    - El informe debe estar integrado dentro de un **Jupyter Notebook**. No es necesario subirlo a una plataforma externa, pero debe cumplir con los siguientes requisitos:
#      - Estructura clara y ordenada.
#      - Código acompañado de explicaciones detalladas.
#      - Resultados presentados de forma visual y analítica.
#
# 2. **Descuento por informes deficientes**:
#    - Cualquier sección del informe que no tenga una explicación adecuada o no respete el formato será penalizada con un descuento en la nota. Esto incluye código sin comentarios o análisis que no sean coherentes con los resultados presentados.
#    - Comentarios sin formatear de ChatGPT o herramientas similares serán penalizados (e.g: "Inserta tu modelo acá", etc.)
#
# # 📬 Entrega Parcial 1 (30% del Proyecto)
#
# ### 📪 Fecha de Entrega: 12 de Septiembre
#
# ## 📌 Abstract [0.25 puntos]
#
# <center>
# <img src="https://i.redd.it/h5ptnsyabqvd1.gif" width="400" height="300">
#
# En esta sección, deben redactar un Abstract claro y conciso para su proyecto. El Abstract debe responder a las siguientes preguntas clave:
#
# - **Descripción del problema**: ¿Cuál es el objetivo del proyecto? ¿Qué se intenta predecir o analizar?
# - **Datos de entrada**: ¿Qué datos tienen disponibles? ¿Cuáles son sus principales características?
# - **Métrica de evaluación**: ¿Cómo medirán el desempeño de sus modelos? Expliquen por qué eligieron esta métrica basándose en el análisis exploratorio de los datos.
# - **Modelos y transformaciones**: ¿Qué modelos utilizarán y por qué? ¿Qué transformaciones o preprocesamientos aplicaron a los datos?
# - **Resultados generales**: ¿El modelo final cumplió con los objetivos del proyecto? ¿Cuáles fueron las conclusiones más importantes?
#
# **Importante**: Escriban esto despues de haber resuelto el resto de la tarea.
#
# > El proyecto busca predecir si un cliente
# x comprará un producto
# y en una semana  t, utilizando información demográfica, de producto (Caracterización de los usuarios como de los productos) y transaccional (Cantidad de compra y fecha de esta). Luego, Se incorporaron variables derivadas como Si el usuario compró la semana anterior, recencia de compra, popularidad previa y frecuencia de compra, además de construir la matriz completa cliente-producto-semana para capturar el comportamiento temporal de manera efectiva.
#
#
# Se evaluaron modelos de clasificación como Random Forest, XGBoost, LightGBM y Regresión Logística, empleando el F1-score de la clase positiva como métrica principal, buscando así el mejor balance posible para predecir si el usuario comprará.
#
# Tras la optimización de hiperparámetros en XGBoost, el modelo alcanzó un F1-score de 0.54, muy superior al azar (0.05), lo que indica que el modelo logra intuir de manera efectiva cuando un comprador volverá a comprar.
#
# El análisis SHAP confirmó que dichas variables  tienen un impacto muy determinante en la predicción de compra. Por lo que para próximos pasos podría ser relevante abordar la disminución del sesgo asociado.
#
# ## 📌 Pre-procesamiento [0.5 puntos]
#
# <center>
# <img src="https://media0.giphy.com/media/10zsjaH4g0GgmY/giphy.gif?cid=6c09b9523xtlunksc9amikw09zk1bmiqwjqnt70ae82rk877&ep=v1_gifs_search&rid=giphy.gif&ct=g" width="400" height="300">
#
# Tal como en muchos otros problemas de negocio, los datos probablemente deben ser pre procesados antes de aplicar cualquier técnica de analítica. Bajo esa premisa, en esta sección deben desarrollar código que les permita **preparar los datos** de tal forma que les permita resolver el problema planteado. Para esto, pueden aplicar procesamientos como:
#
# - Transformaciones de tipo de dato (str, int, etc)
# - Cruce de información
# - Eliminación de duplicados
# - Filtros de fila y/o columnas
#
# *Hint: ¿Qué forma debería tener la data para resolver un problema de aprendizaje supervisado?*
#
# Todo proceso llevado a cabo debe estar bien documentado y justificado en el informe, explicando el por qué se decidió realizar en funcion de los datos presentados y los objetivos planteados del proyecto.

# %%
# !pip install optuna
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.9/400.9 kB 10.0 MB/s eta 0:00:00
# ...

# %%
# Librerias
import gdown
import zipfile
import pandas as pd
import numpy as np
import optuna
import gc
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler, RobustScaler , StandardScaler
from sklearn.impute import SimpleImputer, KNNImputer
from sklearn.metrics import f1_score
from sklearn.model_selection import StratifiedKFold
from xgboost import XGBClassifier
from xgboost.callback import EarlyStopping
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
import time
from sklearn.svm import SVC
from cuml.ensemble import RandomForestClassifier as cuRF
from sklearn.neighbors import KNeighborsClassifier
import lightgbm as lgb
import cupy as cp
import xgboost as xgb
from sklearn.dummy import DummyClassifier
from optuna.integration import XGBoostPruningCallback
import shap
from scipy import sparse
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/optuna/integration/xgboost.py in <module>
#       4 try:
# ----> 5     from optuna_integration.xgboost import XGBoostPruningCallback
#       6 except ModuleNotFoundError:
#
# ModuleNotFoundError: No module named 'optuna_integration'
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/optuna/integration/__init__.py in _get_module(self, module_name)
#     131             try:
# --> 132                 return importlib.import_module("." + module_name, self.__name__)
#     133             except ModuleNotFoundError:
#
# /usr/lib/python3.12/importlib/__init__.py in import_module(name, package)
#      89             level += 1
# ...

# %%
#Carga de Datos (Si se trabaja en colab activar esta celda)
colab=True
if colab:
  file_id = "1okk3ylnHSc-nh8k1ydc2ppeqaWqcFUyn"
  url = f"https://drive.google.com/uc?id={file_id}"

  output = "entrega1.zip"
  gdown.download(url, output, quiet=False)
  with zipfile.ZipFile(output, 'r') as zip_ref:
      zip_ref.extractall("datasets")
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1okk3ylnHSc-nh8k1ydc2ppeqaWqcFUyn
# To: /content/entrega1.zip
# 100%|██████████| 2.13M/2.13M [00:00<00:00, 198MB/s]

# %%
clientes = pd.read_parquet("datasets/clientes.parquet")
productos = pd.read_parquet("datasets/productos.parquet")
transacciones = pd.read_parquet("datasets/transacciones.parquet")

# %%
print(clientes["customer_id"].duplicated().sum())
print(productos["product_id"].duplicated().sum())
print(transacciones.duplicated().sum())
# Out:
# 0
# 0
# 885

# %% [markdown]
# Se observa que hay 885 filas duplicadas en transacciones, por lo que se eliminan a continuación.

# %%
transacciones= transacciones.drop_duplicates()

# %%
print("Clientes:")
print(clientes.dtypes)
print("----")
print("Productos:")
print(productos.dtypes)
print("----")
print("Transacciones:")
print(transacciones.dtypes)
# Out:
# Clientes:
# customer_id               int64
# region_id                 int64
# zone_id                   int64
# customer_type            object
# Y                       float64
# X                       float64
# num_deliver_per_week      int64
# num_visit_per_week        int64
# dtype: object
# ----
# Productos:
# product_id        int64
# brand            object
# category         object
# sub_category     object
# segment          object
# package          object
# size            float64
# dtype: object
# ----
# Transacciones:
# customer_id               int64
# product_id                int64
# order_id                  int64
# purchase_date    datetime64[ns]
# items                   float64
# dtype: object

# %% [markdown]
# Se observa la existencia de muchos parámetros del tipo object, por lo que por estandarización, se prefieren pasar a tipo category, donde antes se estandariza la escritura de estas pasando a minuscula.

# %%
for c in ["brand","category","sub_category","segment","package"]:
    productos[c] = (
        productos[c]
        .str.strip()
        .str.lower()
        .str.replace(r"\s+", " ", regex=True)
    )

    productos[c] = productos[c].astype("category")

clientes['customer_type'] = (clientes['customer_type'].str.strip().str.lower().str.replace(r"\s+", " ", regex=True))

clientes['customer_type'] = clientes['customer_type'].astype("category")

# %%
clientes.isnull().sum()
# Out:
# customer_id             0
# region_id               0
# zone_id                 0
# customer_type           0
# Y                       0
# X                       0
# num_deliver_per_week    0
# num_visit_per_week      0
# dtype: int64

# %%
clientes["X"] = clientes["X"].fillna(clientes["X"].mode()[0])

# %% [markdown]
# Hay un valor nulo, el cual se prefiere abordar rapidamente imputando por la moda.

# %% [markdown]
# Finalmente, al observar la descripción de las columnas, la mayoría podrían tener alguna relevancia, la cual puede ser estudiada en el eda, sin embargo es importante revisar el caso de las variables geográficas, donde hay 4 variables que pueden ser importantes. Donde puede haber multicolinealidad o repetición de información de manera innecesaria. Inicialmente, se considera que latitud y longitud geográfica ("X","Y") pierden toda relevancia si existen parámetros más claros  e interpretables como "zone_id" y "region_id".

# %%
print(clientes[["region_id", "zone_id", "X", "Y"]].nunique())
# Out:
# region_id       1
# zone_id         1
# X            1552
# Y            1548
# dtype: int64

# %% [markdown]
# Como se observa en los valores únicos de region_id, zone_id, X y Y, todos los registros de clientes corresponden a una sola región y zona geográfica. Al no aportar variabilidad, estas columnas sion eliminadas del conjunto de datos.

# %%
clientes.drop(["region_id", "zone_id"], axis=1, inplace=True)

# %% [markdown]
# Se puede estandarizar el texto del dataset,  para que no haya problemas en la  escritura de las categorías en el set de datos, además, se pasa a tipo category.

# %% [markdown]
# Finalmente, para un posterior ahorro de memoria, se hace downcast para disminuir el tamaño del tipo de los datos sin perder información.

# %%
#Downcast Transacciones

for col in ["customer_id","product_id","order_id"]:
    transacciones[col] = pd.to_numeric(transacciones[col], downcast="integer")
transacciones["items"] = pd.to_numeric(transacciones["items"], downcast="float")

#Downcast Clientes

for col in ["customer_id","num_deliver_per_week","num_visit_per_week"]:
    clientes[col] = pd.to_numeric(clientes[col], downcast="integer")

for col in ["Y","X"]:
    clientes[col]=pd.to_numeric(clientes[col], downcast="float")

#Downcast Productos
productos["product_id"] = pd.to_numeric(productos["product_id"], downcast="integer")
productos["size"] = pd.to_numeric(productos["size"], downcast="float")

# %%
print("Clientes:")
print(clientes.dtypes)
print("----")
print("Productos:")
print(productos.dtypes)
print("----")
print("Transacciones:")
print(transacciones.dtypes)
# Out:
# Clientes:
# customer_id                int32
# customer_type           category
# Y                        float32
# X                        float32
# num_deliver_per_week        int8
# num_visit_per_week          int8
# dtype: object
# ----
# Productos:
# product_id         int32
# brand           category
# category        category
# sub_category    category
# segment         category
# package         category
# size             float32
# dtype: object
# ----
# Transacciones:
# customer_id               int32
# product_id                int32
# order_id                  int32
# purchase_date    datetime64[ns]
# items                   float32
# dtype: object

# %% [markdown]
# Finalmente, al observar los dtype de items es float, pero esto no calza con la definición de cantidad de bultos vendido , al no poder existir decimales en este.
#
# Por lo mismo se transforma a int, haciendo aproximación al natural más cercano.
#
# Se mantiene la versión float por si es requerida posteriormente.

# %% [markdown]
# Para hacer el EDA, y solo de manera preliminar, se hace un dataset conjunto de las tres tablas, para poder así hacer un analísis cruzado más completo.

# %%
data= transacciones.merge(clientes, on="customer_id",how="left").merge(productos, on="product_id",how="left")

# %%
data["items_int"] = np.floor(data["items"] + 0.5).astype("Int32")

# %%
data.head()
# Out:
#    customer_id  product_id  order_id purchase_date     items customer_type  \
# 0        61353       61364    411145    2024-04-27 -0.333333     abarrotes
# 1        61899        1370    411156    2024-04-27  3.666667     mayorista
# 2       154077       30500    417911    2024-04-29  2.333333     abarrotes
# 3       164337       56714    418100    2024-04-29 -2.333333     abarrotes
# 4       172056       61672    407162    2024-04-26  1.000000     mayorista
#
#            Y           X  num_deliver_per_week  num_visit_per_week     brand  \
# 0 -46.558720 -107.860565                     3                   1  brand 35
# 1 -46.557632 -107.896469                     3                   1  brand 34
# 2 -46.543598 -107.874168                     3                   1  brand 31
# 3 -46.549961 -107.863091                     3                   1  brand 31
# 4 -46.564529 -107.927650                     4                   1  brand 34
#
# ...

# %% [markdown]
# Todo este pre-procesamiento se hace con un análisis muy preliminar de los datos y por lo mismo no es profundo. Posterior a lo realizado en el análisis de datos, se pueden generar nuevos pre-procesamientos como generación de nuevas variables relevantes, filtros, eliminación, entre otros. Por ejemplo, sabemos que queremos hacer una predicción semanal, sin embargo, antes del EDA no podemos saber si es que los datos estan agrupados por día o por semana, entre otras cosas clave para la generación de nuevas variables.

# %% [markdown]
# ## 📌 EDA [0.5 puntos]
#
# <center>
# <img src="https://media3.giphy.com/media/v1.Y2lkPTc5MGI3NjExbHZ6aGdkd21tYTI3cW8zYWhyYW5wdGlyb2s3MmRzeTV0dzQ1NWlueiZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/3k1hJubTtOAKPKx4k3/giphy.gif" width="400" height="200">
#
# En esta sección, se debe realizar un análisis exploratorio de los datos para comprender su estructura, detectar posibles problemas y obtener información relevante para el entrenamiento de los modelos. La idea es que puedan detectar **patrones en los datos** que les permitan resolver el problema con mayor facilidad.
#
# Se deben responder preguntas a partir de lo que puedan visualizar/obtener, por ejemplo:
#
# - Clientes y productos
#
#     - ¿Cuántos clientes únicos hay en el dataset?
#
#     - ¿Cuántos productos únicos se encuentran en los datos?
#
# - Periodo y frecuencia
#
#     - ¿De qué periodo es la información disponible?
#
#     - ¿Cuál es la frecuencia de los registros (diaria, semanal, mensual, etc.)?
#
# - Calidad de los datos
#
#     - ¿Existen valores nulos en el dataset? ¿Cuántos? ¿Cómo se pueden tratar?
#
#     - ¿Hay datos raros, como cantidades negativas o inconsistencias? Genere tests de validación para identificar estos problemas.
#
# - Patrones de compra
#
#     - ¿Cuántos productos compra en promedio cada cliente semana a semana?
#
#     - ¿Cuántas transacciones ha realizado cada cliente?
#
#     - ¿Cuál es el periodo de recompra promedio de cada SKU?

# %%
print(f"Filas únicas: {data.shape[0]}")
print(f"Cantidad de ordenes: {data['order_id'].nunique()}")
print("---")
print(f"Clientes totales: {clientes['customer_id'].nunique()}")
print(f"Número de clientes con compras: {data['customer_id'].nunique()}")
print("---")
print(f"Número de productos totales: {productos['product_id'].nunique()}")
print(f"Número de productos con ventas: {data['product_id'].nunique()}")
# Out:
# Filas únicas: 254051
# Cantidad de ordenes: 64600
# ---
# Clientes totales: 1569
# Número de clientes con compras: 1490
# ---
# Número de productos totales: 971
# Número de productos con ventas: 114

# %%
data[data["order_id"] == 1215968].head()
# Out:
#         customer_id  product_id  order_id purchase_date      items  \
# 133407       197286       39186   1215968    2024-12-23   2.333333
# 133408       197286       62944   1215968    2024-12-23  -1.666667
# 133474       197286       63218   1215968    2024-12-23   3.000000
# 133594       197286       63218   1215968    2024-12-23  -2.333333
# 133717       197286       63510   1215968    2024-12-23  14.333333
#
#        customer_type          Y           X  num_deliver_per_week  \
# 133407     mayorista -47.111794 -107.974663                     3
# 133408     mayorista -47.111794 -107.974663                     3
# 133474     mayorista -47.111794 -107.974663                     3
# 133594     mayorista -47.111794 -107.974663                     3
# 133717     mayorista -47.111794 -107.974663                     3
#
#         num_visit_per_week     brand              category sub_category  \
# 133407                   1  brand 35  bebidas carbonatadas     gaseosas
# ...

# %% [markdown]
# Vemos que hay casos donde hay más de un order_id, lo que ocurre cuando un cliente compra más de un producto. Por eso aunque hayan 254 mil filas, en verdad el dataset cuenta con 64600 ordenes de transacción.
#
#
#
# Por otro lado, de los 1569 clientes de la tabla clientes, solo 1490 compraron en el año 2024 (se asume que compran en 2024 si aparecen en la tabla de transacciones).
#
# Lo mismo ocurre con productos, de donde de los 970 productos totales, solo 114 han sido vendidos en 2024.

# %% [markdown]
# Existen cerca de 1569 clientes únicos en el dataset, mientras que hay 971 tipos de productos distintos.
#
# El dataset posee información del Año 2024, siendo la primera transacción el 01/01/2024 y la última el 31/12/2024.

# %%
# Transacciones por día.
for mes in range(1, 13):
    df_mes = data[data["purchase_date"].dt.month == mes]

    frecuencia_diaria = df_mes.groupby(df_mes["purchase_date"].dt.date).size()

    plt.figure(figsize=(12,6))
    frecuencia_diaria.plot(kind="bar", color="skyblue", edgecolor="black")
    plt.title(f"Frecuencia de transacciones por día - Mes {mes}")
    plt.xlabel("Día")
    plt.ylabel("Cantidad de transacciones")
    plt.xticks(rotation=45)
    plt.grid(axis="y", alpha=0.4)
    plt.show()

# %% [markdown]
# En este caso, se observa como la frecuencia de los registros es diaria, al haber entradas de datos todos los días del año. Al hacer los gráficos, se puede observar que en general todos los meses tienen un comportamiento similar, con meses con más ventas en general (Por ejemplo, Diciembre).
# Además, se observan ciertos peaks de compra en cada mes.

# %%
#Transacciones por día.
diario = data.groupby(data["purchase_date"].dt.normalize()).size()
prom = diario.groupby(diario.index.dayofweek).mean().reindex(range(7))
dias = ["Lunes","Martes","Miércoles","Jueves","Viernes","Sábado","Domingo"]

plt.figure(figsize=(9,4))
bars = plt.bar(dias, prom.values, edgecolor="black")
plt.title("Promedio de transacciones por día de la semana")
plt.xlabel("Día"); plt.ylabel("Promedio de transacciones por día")
plt.grid(axis="y", alpha=0.3)


for b, v in zip(bars, prom.values):
    plt.text(b.get_x()+b.get_width()/2, b.get_height()*1.01, f"{v:.1f}",
             ha="center", va="bottom", fontweight="bold", fontsize=6.5)

plt.tight_layout()
plt.show()

# %% [markdown]
# Si agrupamos las ventas por día, se observa una estacionalidad semanal muy marcada. Donde en general,los fines de semana la cantidad de transacciones disminuye fuertemente.

# %%
#Calidad de Datos.
data.describe()
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254051 entries, 0 to 254050
# Data columns (total 17 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   customer_id           254051 non-null  int32
#  1   product_id            254051 non-null  int32
#  2   order_id              254051 non-null  int32
#  3   purchase_date         254051 non-null  datetime64[ns]
#  4   items                 254051 non-null  float32
#  5   customer_type         254051 non-null  category
#  6   Y                     254051 non-null  float32
#  7   X                     254051 non-null  float32
#  8   num_deliver_per_week  254051 non-null  int8
#  9   num_visit_per_week    254051 non-null  int8
#  10  brand                 254051 non-null  category
#  11  category              254051 non-null  category
#  12  sub_category          254051 non-null  category
#  13  segment               254051 non-null  category
# ...

# %% [markdown]
# De manera inicial, se observa que no existen valores nulos para ninguna columna.
#
# Sin embargo, Pueden haber nulos ocultos en las filas tipo string, con entradas como "No existe", "No aplica", "-", entre otras.
#
# Además, es relevante verificar los valores y distribuciones de estas columnas para análisis posteriores.

# %%
import matplotlib.pyplot as plt

for c in ["customer_type","brand","category","sub_category","segment","package"]:
    vc = data[c].value_counts(dropna=False)
    fig, ax = plt.subplots(figsize=(11, 4 + 0.22*len(vc)))
    bars = ax.barh(vc.index.astype(str), vc.values, height=0.45, edgecolor="black")
    ax.invert_yaxis()
    ax.set_title(f"Distribución de {c}")
    ax.set_xlabel("Conteo")
    ax.grid(axis="x", alpha=0.3)

    ax.bar_label(
        bars,
        labels=[f"{v:,} ({v/vc.sum():.1%})" for v in vc.values],
        padding=3,
        fontsize=10,
        fontweight="bold"
    )

    plt.tight_layout()
    plt.show()

# %% [markdown]
# En los gráficos anteriores se observa que efectivamente no hay valores nulos en el set de datos que hayan estado ocultos con valores como "Sin información", "N/A", "-" , etc.
#
# Analizando por columna, se observa que en cuanto a customer_type, la gran mayoría de los clientes se catalogan del tipo abarrotes (59.5%), seguido por mayorista (26.5%), las otras clases son más minoritarias.
#
# En cuanto a la columna de brand.
# Se observa un dominio en la cantidad de ventas entre 3 marcas que superan el 17% cada una. (34,3 y 31).
#
# Estas son Seguidas de cerca por Brand 44,24 y 35.
#
# Luego hay brands como 1 con un peso leve en las ventas, y marcas mucho más pequeñas, como 55, 28 o 52 que tienen un peso muy marginal en la cantidad de datos.
#
# En la columna category se observa solo la venta de bebidas carbonatadas, con un 100% de los datos, por lo cual es una columna totalmente eliminable al no tener información asociada que pueda aportar en una clasificación.
#
# En cuanto a sub categoria, solo un 0.2% de los datos corresponden a aguas saborizadas, mientras que todo el resto son gaseosas.
#
# El segmmento mayoritario de los productos que se venden son del tipo medio, con casi la mitad de las ventas realizadas (48.6%), seguido por premium (22.2%), high (16.6%) y finalmente low (12.6%).
#
# En cuanto al empaquetado, un 62% de las bebidas se embotellan, el resto son enlatadas y una proporcion muy menor (0.3%) se vende en barriles.
#
# Finalmente, se observa que todos los datos corresponden a la región 80. Por lo que nuevamente es una columna eliminable del set de datos, al no generar información diferenciada.
#
# Inicialmente, se tenía la idea de generar un gráfico de transacciones por zona para cada región, sin embargo como se observo anteriormente, hay una sola región.  Posterior a esto, se nota que además, existe una sola zona, por lo que ninguna de estas columnas entrega nueva información y se justifica la eliminación anterior de estas al no diferenciar la venta de los productos.

# %% [markdown]
# Ahora se pueden observar los mismos tipos de datos para las variables numéricas, con la finalidad de observar distribuciones marcadas, datos atípicos  y valores incosistentes de la manera más sencilla posible.

# %%
import matplotlib.pyplot as plt
import numpy as np

num_cols = ["num_deliver_per_week","num_visit_per_week","items_int","size"]

for c in num_cols:
    fig, ax = plt.subplots(figsize=(8,4))
    n, bins, patches = ax.hist(data[c].dropna(), bins=30, edgecolor="black")
    total = n.sum()
    ax.set_ylim(0, n.max()*1.15)
    ax.set_title(f"Histograma de {c}")
    ax.set_xlabel(c)
    ax.set_ylabel("Frecuencia")
    ax.grid(axis="y", alpha=0.3)

    for bar, count in zip(patches, n):
        if count <= 0:
            continue
        x = bar.get_x() + bar.get_width()/2
        y = bar.get_height()
        ax.text(x, y + n.max()*0.02, f"{int(count):,} ({count/total:.1%})",
                ha="center", va="bottom", fontsize=9, fontweight="bold")

    plt.tight_layout()
    plt.show()

# %% [markdown]
# En los gráficos anteriores se observa que la gran mayoría de clientes piden 3 deliver por semanas, superando los 200 mil datos. Para 4, este valor baja considerablemente a cerca de 40 mil, mientras que para 2, 5, y 6 el valor es de la frecuencia es mucho menor. Además, para las visitas por semana, son siempre 1, por lo que nuevamente es una variable que no entrega información. y se puede eliminar.
#
# En items (int) se observan datos demasiado ruidosos, donde hay muchos datos con valores "0" y un valor muy alejado del resto.
#
# Para el gráfico anterior, las etiquetas de los datos en el gráfico generan mucho ruido y no son agradables visualmente, sin embargo, le encontramos valor al poder verificar el ruido existente.
#
# En cuanto a size, también se encuentra en un valor muy alejado, se encuentra que la gran mayoría de los datos tienen un size menor.
#
# Existen 724 datos con un tamaño mucho mayor (20), pero como se ve a continuación, corresponden con las ventas de tipo barril.

# %%
data.loc[data["package"]=="keg","size"].value_counts()
# Out:
# size
# 20.0    724
# Name: count, dtype: int64

# %% [markdown]
# Dada la gran cantidad de datos de latitud y longitud anteriormente vistos, se omitieron estas variables para los gráficos anteriores, a continuación se realiza un gráfico para mostrar la distribución geográfica de los clientes.

# %%
plt.scatter(clientes["X"], clientes["Y"], alpha=0.5)
plt.title("Distribución geográfica de clientes")
plt.xlabel("Longitud (X)")
plt.ylabel("Latitud (Y)")
plt.show()

# %% [markdown]
# Se observan así, dos grupos geográficos claros entre los clientes, uno más masivo, , cercano al punto (-110,-40) y otro, minoritario, cercano a (-40,-110).
#
# Debido a la simetría casi inversa entre ambos grupos, podría interpretarse que los registros minoritarios corresponden a un error de entrada en los datos geográficos, considerando además que todos los clientes pertenecen a una misma región y zona.
#
# No obstante, dado que la cantidad de casos minoritarios es muy reducida, se evita introducir ruido potencialmente artificial, por lo que se opta por mantenerlos en el dataset tal como aparecen.

# %% [markdown]
# Para complementar el gráfico totalmente ruidoso de items, se puede mostrar una tabla con la frecuencia de cada dato, además de un boxenplot, el cual sigue sin ser claro, dada la alta variabilidad de los datos.

# %%
sns.boxenplot(x=data["items_int"])
plt.title("Boxenplot de items")
plt.show()

# %%
pd.set_option("display.max_rows", None)
data["items_int"].value_counts().sort_index()
# Out:
# items_int
# -400        1
# -266        1
# -233        2
# -224        6
# -200        1
# -186        2
# -176        3
# -166        2
# -133        5
# -100        4
# -88         1
# -86         2
# -80         1
# -73         1
# -66        46
# -63         1
# -60         1
# -56         1
# -53         8
# -50         1
# -46         7
# -44         2
# -40         8
# -38         3
# -34         1
# -33        79
# -30         3
# -28         2
# -26        20
# -25         1
# -23        10
# -22         1
# -20        95
# -18         9
# -16        34
# -15         6
# -14        11
# -13       189
# -12        10
# -11        12
# -10       128
# -9         12
# -8         74
# -7         13
# -6        551
# -5        107
# -4        402
# -3        714
# -2       1645
# -1       1852
# 0        2313
# 1       62800
# 2       82051
# 3       17446
# 4       33227
# 5        3135
# 6        4602
# 7       16779
# 8        1958
# 9         454
# 10       5530
# ...

# %% [markdown]
# Se observan los datos anómalos de items, considerando como anómalos los datos que tienen valores . ya que no es una venta como tal una transacción negativa <0.

# %%
print("Datos items con valores negativos:",(data["items"] < 0).sum())
# Out:
# Datos items con valores negativos: 8346

# %%
#Patrones de compra
plt.figure(figsize=(12,6))

counts = (
    data.assign(week=data['purchase_date'].dt.strftime('%U'))
        .groupby(['customer_id','week'])['product_id'].nunique()
        .reset_index(name='productos en semana')
        .groupby('customer_id')['productos en semana'].mean()
        .reset_index(name='avg_items_per_week')
        .assign(
            avg_range=lambda df: pd.cut(
                df['avg_items_per_week'],
                bins=list(range(0, int(np.ceil((df['avg_items_per_week'].max() + 1)/10)*10) + 1, 10)),
                right=False,
                labels=[
                    f"[{i},{i+10})" for i in range(0, int(np.ceil((df['avg_items_per_week'].max() + 1)/10)*10), 10)
                ],
                include_lowest=True
            )
        )['avg_range']
        .value_counts()
        .sort_index()
)

ax = counts.plot(kind="bar", color="lightgreen", edgecolor="black")

plt.xticks(rotation=90)
plt.xlabel("Rango de ítems promedio por semana")
plt.ylabel("Número de clientes")
plt.title("Distribución de clientes por promedio semanal de ítems")
plt.tight_layout()

ymax = counts.max()
for bar, count in zip(ax.patches, counts.values):
    if count <= 0:
        continue
    x = bar.get_x() + bar.get_width()/2
    y = bar.get_height()
    ax.text(x, y + ymax*0.02, f"{int(count):,}",
            ha="center", va="bottom", fontsize=9, fontweight="bold")

plt.show()

# %% [markdown]
# A partir del grafico, donde se expone el promedio semanal de ítems por cantida de clientes, se evidencia que la gran mayoría de los clientes compra en promedio entre 0 y 10 ítems por semana, lo que indica que el comportamiento típico es de bajo volumen semanal.

# %%
data[['customer_id','order_id']].value_counts().head(20)
# Out:
# customer_id  order_id
# 197286       1215968     37
# 71274        23039       35
# 203151       869363      34
# 204189       1236631     34
# 249342       1005970     34
# 186933       1074450     34
# 221331       458639      32
# 186933       878313      32
# 238293       855334      30
# 183492       323491      30
# 183105       1108777     30
# 220269       865033      29
# 188331       895782      29
# 204189       340251      29
# 186174       311916      29
# 187806       391447      29
# 210615       256565      28
# 203829       1216159     28
# 211815       859754      28
# 205191       1016748     28
# Name: count, dtype: int64

# %%
# Cada transacción se identifica con order_id y como se ve arriba, existe repeticion (usamos nunique)
plt.figure(figsize=(12,6))

counts = (
    data.groupby('customer_id')['order_id'].nunique()
        .reset_index(name='num_transactions')
        .assign(
            tx_range=lambda df: pd.cut(
                df['num_transactions'],
                bins=list(range(
                    0,
                    int(np.ceil((df['num_transactions'].max() + 1)/10)*10) + 1,
                    10
                )),
                right=False,
                labels=[
                    f"[{i},{i+10})"
                    for i in range(0, int(np.ceil((df['num_transactions'].max() + 1)/10)*10), 10)
                ],
                include_lowest=True
            )
        )['tx_range']
        .value_counts()
        .sort_index()
)

ax = counts.plot(kind="bar", color="skyblue", edgecolor="black")

plt.xticks(rotation=90)
plt.xlabel("Rango de transacciones")
plt.ylabel("Número de clientes")
plt.title("Distribución de clientes por rango de transacciones")
plt.tight_layout()

ymax = counts.max()
for bar, count in zip(ax.patches, counts.values):
    if count <= 0:
        continue
    x = bar.get_x() + bar.get_width()/2
    y = bar.get_height()
    ax.text(x, y + ymax*0.02, f"{int(count):,}",
            ha="center", va="bottom", fontsize=9, fontweight="bold")

plt.show()

# %% [markdown]
# A partir del grafico, donde se expone el numero de transacciones por cantidad de cliente, se evidencia que la mayoría de clientes acumula entre 10 y 50 transacciones, con un peak en el rango de 20 a 40. Luego, a medida que aumenta el número de transacciones, el número de clientes disminuye de forma progresiva.

# %%
#Identificamos SKU por product_id y vemos cada cuanto se vuelve a comprar

plt.figure(figsize=(12,6))

counts = (
    data.sort_values(['product_id', 'purchase_date'])
        .assign(days_diff=lambda df: df.groupby('product_id')['purchase_date'].diff().dt.days)
        .groupby('product_id')['days_diff'].mean()
        .dropna()
        .pipe(lambda s: pd.cut(
            s,
            bins=list(range(0, int(np.ceil((s.max() + 1)/10)*10) + 1, 10)),
            right=False,
            labels=[f"[{i},{i+10})" for i in range(0, int(np.ceil((s.max() + 1)/10)*10), 10)],
            include_lowest=True
        ))
        .value_counts()
        .sort_index()
)


ax = counts.plot(kind="bar", color="salmon", edgecolor="black")

plt.xticks(rotation=90)
plt.xlabel("Rango de promedio de recompra (días)")
plt.ylabel("Número de SKUs")
plt.title("Distribución de SKUs por promedio de recompra")
plt.tight_layout()


ymax = counts.max()
for bar, count in zip(ax.patches, counts.values):
    if count <= 0:
        continue
    x = bar.get_x() + bar.get_width()/2
    y = bar.get_height()
    ax.text(x, y + ymax*0.02, f"{int(count):,}",
            ha="center", va="bottom", fontsize=9, fontweight="bold")

plt.show()

# %% [markdown]
# A partir del grafico, donde se expone el promedio de recompra por SKU (realizado a partir del ID de los productos), se evidencia que casi todos los SKU's tienen un promedio de recompra muy bajo (menos de 10 días) y existen algunos SKUs con ciclos de recompra más largos, pero son casos muy aislados.

# %% [markdown]
# A partir de los 3 graficos expuestos anteriormente, asociados a los patrones de compra, se evidencia que, en promedio, los clientes suelen comprar pocos ítems distintos por semana, realizando, mayormente, entre 20 y 40 transacciones en el periodo, mientras que los SKUs tienen una recompra muy rápida, lo que sugiere que la mayoria son productos de alta rotación (o bien, de "consumo rapido").

# %%
data.head()
# Out:
#    customer_id  product_id  order_id purchase_date     items customer_type  \
# 0        61353       61364    411145    2024-04-27 -0.333333     abarrotes
# 1        61899        1370    411156    2024-04-27  3.666667     mayorista
# 2       154077       30500    417911    2024-04-29  2.333333     abarrotes
# 3       164337       56714    418100    2024-04-29 -2.333333     abarrotes
# 4       172056       61672    407162    2024-04-26  1.000000     mayorista
#
#            Y           X  num_deliver_per_week  num_visit_per_week     brand  \
# 0 -46.558720 -107.860565                     3                   1  brand 35
# 1 -46.557632 -107.896469                     3                   1  brand 34
# 2 -46.543598 -107.874168                     3                   1  brand 31
# 3 -46.549961 -107.863091                     3                   1  brand 31
# 4 -46.564529 -107.927650                     4                   1  brand 34
#
# ...

# %% [markdown]
# Ahora con lo visto en el EDA, se vuelve al preprocesamiento antes de pasar al feature engineering. Como se menciono anteriormente, el uso de data, era temporal, por lo que ahora se vuelve a las tres tablas existentes de base.
#
# Principalmente, es necesario acomodar los datos de la manera correcta para poder ser entrenados en el modelo.
#
# creamos las variables de "week_date" (Fecha en la que comienza la semana) y "week" (Numero de semana en la que se encuentra, partiendo como 1 la primera semana del dataset)

# %%
transacciones["week_date"] = transacciones["purchase_date"].dt.to_period("W").apply(lambda r: r.start_time)

transacciones = transacciones.sort_values("week_date")
transacciones["week"] = pd.factorize(transacciones["week_date"])[0] + 1
transacciones["month"]= transacciones["purchase_date"].dt.month

# %%
transacciones.head()
# Out:
#          customer_id  product_id  order_id purchase_date     items  week_date  \
# 2744348       223782        1304      8980    2024-01-03  2.333333 2024-01-01
# 3489518       210690       60978     17411    2024-01-05  1.666667 2024-01-01
# 3489515       208572        1370     17354    2024-01-05  1.666667 2024-01-01
# 3489514       208524       44302     17349    2024-01-05  7.000000 2024-01-01
# 3489509       203700       35732     17229    2024-01-05  1.666667 2024-01-01
#
#          week  month
# 2744348     1      1
# 3489518     1      1
# 3489515     1      1
# 3489514     1      1
# 3489509     1      1

# %% [markdown]
# Posterior a esto, se crea el nuevo dataset a trabajar, llamado "weekly", el cual agrupa los datos por semana.
#
# Como en general los datos son de productos o clientes, se mantienen iguales al estar ligados a la id, la cual va agrupada.
#
# Sin embargo, es importante saber cuantos pedidos se agrupan en una sola semana, y cuantos items se tienen. Los cuales son información muy valiosa que se pierde si no se hace en el paso de la agrupación.

# %%
weekly = (
    transacciones.groupby(["customer_id", "product_id", "week"], as_index=False)
    .agg(
        items=("items", "sum"),         # cuántas unidades de ese producto compró en la semana
        n_orders=("order_id", "nunique"), # cuántos pedidos distintos hizo (puede ser 1 o más)
        month =("month", "first")
    )
)

# %% [markdown]
# Ahora que los datos de items ya fueron agrupados, se puede realizar el redondeo y traspaso a entero, con la finalidad de no acumular error de aproximación si es que se consideraba items_int.

# %%
weekly["items"] = np.floor(weekly["items"] + 0.5).astype("Int32")
weekly["n_orders"] = weekly["n_orders"].astype("int32")

# %%
weekly.head()
# Out:
#    customer_id  product_id  week  items  n_orders  month
# 0        25734         124     4      2         1      1
# 1        25734        1304     2      7         1      1
# 2        25734        1304     6      2         1      2
# 3        25734        1370     1      4         1      1
# 4        25734        1370     2      3         1      1

# %%
print(weekly.dtypes)
# Out:
# customer_id    int32
# product_id     int32
# week           int64
# items          Int32
# n_orders       int32
# month          int32
# dtype: object

# %% [markdown]
# Ahora, se puede complementar el análisis anterior observando la cantidad de pedidos semanales que un clienta tenga.

# %%
ig, ax = plt.subplots(figsize=(8,4))

counts = weekly["n_orders"].value_counts().sort_index()
bars = ax.bar(counts.index.astype(str), counts.values, edgecolor="black", color="lightgreen")

ax.set_title("Distribución de pedidos semanales (n_orders)")
ax.set_xlabel("Número de pedidos en la semana (cliente–producto)")
ax.set_ylabel("Frecuencia")


for bar, count in zip(bars, counts.values):
    x = bar.get_x() + bar.get_width()/2
    y = bar.get_height()
    ax.text(x, y + counts.max()*0.02, f"{int(count):,}",
            ha="center", va="bottom", fontsize=7, fontweight="bold")

plt.tight_layout()
plt.show()

# %% [markdown]
# Además, es importante revisar la nueva distribución de los datos de items.

# %%
fig, axes = plt.subplots(1, 2, figsize=(14,6))
sns.boxenplot(x=data["items"], ax=axes[0], color="skyblue")
axes[0].set_title("Boxenplot de items (transacciones)")


sns.boxenplot(x=weekly["items"], ax=axes[1], color="lightgreen")
axes[1].set_title("Boxenplot de items (weekly)")

plt.tight_layout()
plt.show()

# %% [markdown]
# Tras el cambio de agrupación semanal, ya no hay datos negativos para items, lo que confirma la teoría de que los items negativos eran devoluciones y se observa una concentración más clara en valores cercanos a 0, hay unos cuantos outliers de ventas sobre 600 items.
#
# Esto concuerda claramente con que valores negativos corresponden a devolución de productos, por lo que no eran valores incorrectos y de hecho, es clave su interpretación para el modelo.
#
# Es muy importante clarificar que por simplicidad y lógica, no se tomará en cuenta como una venta exitosa, que un cliente haya comprado en una semana y luego haya devuelto todo. Es necesario que al menos el cliente se haya quedado con un solo item, si no, para SodAI Drinks, el modelo no tendría sentido.

# %% [markdown]
# Así, finalmente se define la variable objetivo como "compra", donde toma 1 si el cliente x compra el producto y en la semana t. y 0 si no.

# %%
weekly["compra"] = (weekly["items"] > 0).astype("int8")

# %% [markdown]
# Tras generar la variable objetivo, como el set de datos es de compras, es claro notar que las clases estan desbalanceadas, ya que en general, salvo casos especiales de devoluciones totales, se tiene una cantidad positiva de items.

# %%
weekly['compra'].value_counts()
# Out:
# compra
# 1    206431
# 0        29
# Name: count, dtype: int64

# %% [markdown]
# Por lo mismo, y aunque ahora haya un desbalance para el otro lado. Para tener un funcionamiento total del modelo, el dataset debe contener todos los datos de todas las combinaciones posibles de cliente, producto y semana. Para así mostrar cuando compra o no compra y poder hacer la clasificación binaria.

# %%
weeks_total = weekly["week"].unique()
customers_total = weekly["customer_id"].unique()
products_total = weekly["product_id"].unique()


idx = pd.MultiIndex.from_product([customers_total, products_total, weeks_total],
                                 names=["customer_id","product_id","week"])
full = pd.DataFrame(index=idx).reset_index()

#Se calculan todas las combinaciones posibles de los productos clientes y semanas en el dataset.
weekly_full = full.merge(weekly[["customer_id","product_id","week",'items','n_orders']], on=["customer_id","product_id","week"], how="left")

weekly_full = weekly_full.merge(clientes, on="customer_id", how="left")
weekly_full=  weekly_full.merge(productos, on="product_id", how="left")

# %%
#Finalmente, rellenamos de ceros tanto las variables como las variables objetivo donde corresponde.
weekly_full["items"]    = weekly_full["items"].fillna(0).astype("int32")
weekly_full["n_orders"] = weekly_full["n_orders"].fillna(0).astype("int32")
weekly_full["compra"]   = (weekly_full["items"] > 0).astype("int8")

# %%
weekly_full.head()
# Out:
#    customer_id  product_id  week  items  n_orders customer_type         Y  \
# 0        25734         124     4      2         1     abarrotes -46.45126
# 1        25734         124     2      0         0     abarrotes -46.45126
# 2        25734         124     6      0         0     abarrotes -46.45126
# 3        25734         124     1      0         0     abarrotes -46.45126
# 4        25734         124     5      0         0     abarrotes -46.45126
#
#             X  num_deliver_per_week  num_visit_per_week     brand  \
# 0 -107.099792                     4                   1  brand 34
# 1 -107.099792                     4                   1  brand 34
# 2 -107.099792                     4                   1  brand 34
# 3 -107.099792                     4                   1  brand 34
# 4 -107.099792                     4                   1  brand 34
#
#                category sub_category segment package  size  compra
# ...

# %%
weekly_full['compra'].value_counts()
# Out:
# compra
# 0    8796149
# 1     206431
# Name: count, dtype: int64

# %% [markdown]
# Posterior a esto, la mayoría de los casos son casos de no compra, lo que era esperable considerando la gran variedad de productos.
#
# Así, el set de datos queda listo para el resto de procesamiento y feature engineering.

# %% [markdown]
# ## 📌 Holdout [0.25 puntos]
#
# Para evaluar correctamente el modelo y garantizar su capacidad de generalización, se deben dividir los datos en tres conjuntos:
# - `Entrenamiento` : Para ajustar los parámetros.
# - `Validación`: Para optimizar hiperparámetros y seleccionar el mejor modelo.
# - `Prueba` : Para evaluar el rendimiento final en datos no vistos.
#
# 👀 **Hint**: *Recuerde que los datos tienen una temporalidad que debe considerarse al momento de separarlos, para evitar fugas de información. Es importante justificar la estrategia de partición elegida y visualizar la distribución temporal de los conjuntos generados*

# %%
weekly_full.head()
# Out:
#    customer_id  product_id  week  items  n_orders customer_type         Y  \
# 0        25734         124     4      2         1     abarrotes -46.45126
# 1        25734         124     2      0         0     abarrotes -46.45126
# 2        25734         124     6      0         0     abarrotes -46.45126
# 3        25734         124     1      0         0     abarrotes -46.45126
# 4        25734         124     5      0         0     abarrotes -46.45126
#
#             X  num_deliver_per_week  num_visit_per_week     brand  \
# 0 -107.099792                     4                   1  brand 34
# 1 -107.099792                     4                   1  brand 34
# 2 -107.099792                     4                   1  brand 34
# 3 -107.099792                     4                   1  brand 34
# 4 -107.099792                     4                   1  brand 34
#
#                category sub_category segment package  size  compra
# ...

# %%
wmin, wmax = int(weekly_full["week"].min()), int(weekly_full["week"].max())
weeks_total = (wmax - wmin + 1)

train_weeks = np.arange(wmin, wmin + int(weeks_total * 0.70))
val_weeks   = np.arange(train_weeks[-1] + 1, wmin + int(weeks_total * 0.85))
test_weeks  = np.arange(val_weeks[-1] + 1, wmax + 1)

train_data = weekly_full[weekly_full["week"].isin(train_weeks)]
val_data   = weekly_full[weekly_full["week"].isin(val_weeks)]
test_data  = weekly_full[weekly_full["week"].isin(test_weeks)]

# --- gráfico ---
fig, ax = plt.subplots(figsize=(14,6))

c = train_data.groupby("week")["compra"].sum().sort_index()
ax.bar(c.index, c.values, alpha=0.7, label="Train")

c = val_data.groupby("week")["compra"].sum().sort_index()
ax.bar(c.index, c.values, alpha=0.7, label="Validation")

c = test_data.groupby("week")["compra"].sum().sort_index()
ax.bar(c.index, c.values, alpha=0.7, label="Test")

ax.set_xticks(np.arange(wmin, wmax+1))
plt.xticks(rotation=90)
plt.xlabel("Semana (número)")
plt.ylabel("N° de compras (sum de compra=1)")
plt.title("Distribución temporal de compras (split por semanas completas)")
plt.legend()
plt.tight_layout()
plt.show()

# %%
weekly = weekly.sort_values(["customer_id","product_id","week"]).reset_index(drop=True)

# %% [markdown]
# ## 📌 Feature Engineering [0.5 puntos]
#
# <center>
# <img src="https://i.imgur.com/CmXZSSC.gif" width="300" height="200">
#
# En esta sección, se deben construir pipelines para automatizar el preprocesamiento de los datos, lo cual garantizará que el flujo de trabajo sea reproducible y eficiente para esta entrega y las futuras. El objetivo es aplicar una serie de transformaciones en un orden definido para asegurar que los datos estén listos para los modelos a entrenar. El pipeline final debe incluir las técnicas de pre-procesamiento que se deben aplicar a los distintos datos (según lo que consideren necesario para el problema). Por ejemplo:
#
# - **Imputación de valores nulos**: Manejo de datos faltantes mediante estrategias adecuadas (media, mediana, moda, interpolación, etc.).
#
# - **Transformaciones personalizadas**: Uso de ColumnTransformer para aplicar diferentes transformaciones a columnas específicas.
#
# - **Codificación de variables categóricas**: Convertir datos categóricos a un formato numérico adecuado (One-Hot Encoding, Label Encoding, etc.).
#
# - **Discretización de variables**: Conversión de variables numéricas continuas en categorías si son relevantes para el desempeño del modelo a entrenar.
#
# - **Estandarización o normalización** : Ajustar la escala de los datos para mejorar el rendimiento de los algoritmos sensibles a la magnitud de las variables.
#
# - **Eliminación o transformación de valores atípicos**: Identificar y tratar con datos outliers para mejorar la robustez del modelo.
#
# - **Nuevas características** : Creación de variables adicionales que puedan aportar información relevante al modelo.
#
# Cada una de estas transformaciones debe ser justificada en función de su relevancia para el problema y los datos, y es importante evaluar su impacto en el rendimiento del modelo. Además, el pipeline debe ser flexible y modular para poder probar diferentes configuraciones de preprocesamiento.

# %% [markdown]
# Inicialmente, se generan las clases necesarias para el pipeline.

# %% [markdown]
# Se agrega la clase Básica de IQR

# %%
class IQR(BaseEstimator, TransformerMixin):
    def __init__(self, lambd=1.5):
        self.lambd = lambd
        self.bounds_ = {}

    def fit(self, X, y=None):

        n_cols = X.select_dtypes(include=[np.number]).columns
        for col in n_cols:
            Q1, Q3 = X[col].quantile([0.25, 0.75])
            IQR = Q3 - Q1
            self.bounds_[col] = (Q1 - self.lambd * IQR, Q3 + self.lambd * IQR)
        return self

    def transform(self, X):
        X = X.copy()
        for col, (inf, sup) in self.bounds_.items():
            mask = (X[col] < inf) | (X[col] > sup)
            X.loc[mask, col] = np.nan
        return X

    def set_output(self, transform="default"):
        return self

    def get_feature_names_out(self, input_features=None):
        return np.asarray(input_features, dtype=object)

# %% [markdown]
# Luego, tanto items como n_orders, serían una fuente de la variable dependiente si se usan tal cual, y no tiene sentido predecir si vendí en una semana en la que se que vendí 3 productos. Por lo mismo, es necesario mover este tipo de variables una semana en el pasado, para que los datos de la semana 3, en realidad tengan cuanto compró el usuario en la semana 2 y así poder predecir de manera correcta 3. Luego, por la misma razón, es necesario en el pipeline eliminar la variable de items y de n_orders. Dichas variables pueden ser redundantes, pero también puede aportar información no vista en "compra_prev"

# %%
class DatosHistoricos(BaseEstimator, TransformerMixin):
    def __init__(self, c="customer_id", p="product_id",
                 week_col="week", items="items", n_orders="n_orders", compra="compra"):
        self.c, self.p, self.week_col = c, p, week_col
        self.items, self.n_orders, self.compra = items, n_orders, compra

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        df = X.copy().sort_values([self.c, self.p, self.week_col]).reset_index(drop=True)

        # Shift históricos
        df["items_prev"]    = (
            df.groupby([self.c, self.p], sort=False)[self.items]
              .shift(1).fillna(0).astype("int16")
        )

        df["compra_prev"]   = (
            df.groupby([self.c, self.p], sort=False)[self.compra]
              .shift(1).fillna(0).astype("int8")
        )

        return df
    def set_output(self, transform="default"):
        return self

# %% [markdown]
# Luego, es importante generar variables de recencia, las cuales son cuanto tiempo ha pasado desde que un cliente no ha hecho una compra. En este caso se define el inicio de la recencia como 1000, y como se vió anteriormente, si un cliente compra, no pasa mucho tiempo en que vuelva a comprar.

# %%
from sklearn.base import BaseEstimator, TransformerMixin

class RecenciaSemanal(BaseEstimator, TransformerMixin):
    def __init__(self, c="customer_id", p="product_id",
                 week_col="week", compra="compra", inicio=1000):
        self.c, self.p, self.week_col, self.compra = c, p, week_col, compra
        self.inicio = inicio

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        df = X.copy().sort_values([self.c, self.p, self.week_col])

        wk     = df[self.week_col]
        bought = df[self.compra].astype(bool)

        # Semana de la última compra del mismo producto.
        last_prod = (
            wk.where(bought)                                   # semanas solo donde hubo compra
              .groupby([df[self.c], df[self.p]], sort=False)
              .ffill()                                         # última compra conocida
              .groupby([df[self.c], df[self.p]], sort=False)
              .shift(1)
        )

        # Recencia
        df["recencia_producto"] = (wk - last_prod).fillna(self.inicio).astype("int16")
        return df

    def set_output(self, transform="default"):
        return self

# %% [markdown]
# Además, podría ser relevante saber si el producto está siendo popular actualmente entre los clientes, nuevamente es necesario ver lo de la semana anterior, ya que ver la semana actual sería filtrar los datos en el modelo.

# %%
class PopularidadProductoPrev(BaseEstimator, TransformerMixin):
    def __init__(self, p="product_id", week_col="week", compra="compra"):
        self.p, self.week_col, self.compra = p, week_col, compra

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        df = X.copy().sort_values([self.p, self.week_col])

        # compras por producto-semana
        n = (df.groupby([self.p, self.week_col], sort=False)[self.compra].sum().groupby(level=0, sort=False).shift(1).rename("popularity_prev").reset_index())

        df = df.merge(n, on=[self.p, self.week_col], how="left")
        df["popularity_prev"] = df["popularity_prev"].fillna(0).astype("float32")
        return df

    def set_output(self, transform="default"):
        return self

# %% [markdown]
# Esta clase incluye dos variables para calcular el ratio de cada cuanto compra el producto "y", además de calcular de cada cuantas compras de producto, compra "y".

# %%
import numpy as np
from sklearn.base import BaseEstimator, TransformerMixin

class CompraRelativa(BaseEstimator, TransformerMixin):
    def __init__(self, c="customer_id", p="product_id", week_col="week", compra="compra"):
        self.c, self.p, self.week_col, self.compra = c, p, week_col, compra

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        df = X.copy().sort_values([self.c, self.p, self.week_col])
        g_cp = df.groupby([self.c, self.p], sort=False)
        g_cw = df.groupby([self.c, self.week_col], sort=False)

        compras_prev = g_cp[self.compra].cumsum().shift(1).fillna(0.0)
        n_prev = g_cp.cumcount()
        df["frec_producto"] = np.where(n_prev > 0, compras_prev / n_prev, 0.0).astype("float32")
        return df

    def set_output(self, transform="default"):
        return self

# %% [markdown]
# Finalmente, agregamos variables del tipo Media Movil exponencial, con suavizamiento exponencial de 4 semanas, para saber que tan activo ha estado el cliente en el último mes. Se hace exponencial y no simple para hacerla menos costosa.

# %%
nuevas_features = Pipeline([
    ("hist", DatosHistoricos()),
    ("rec",  RecenciaSemanal(inicio=1000)),
    ("pop",  PopularidadProductoPrev()),
    ("rel",  CompraRelativa()),
])
nuevas_features.set_output(transform="pandas")

df_feat = nuevas_features.fit_transform(weekly_full)

# %% [markdown]
# Finalmente podemos revisar las distintas variables, observando los datos de productos que compra un usuario especifico

# %%
comprados = (
    df_feat
    .loc[
        (df_feat["customer_id"] == 25734) &
        (df_feat["compra"] == 1),
        "product_id"
    ]
    .unique()
)

comprados
# Out:
# array([  124,  1304,  1370,  1372, 10652, 11262, 30500, 33886, 35732,
#        39186, 46632, 50720, 54096, 56714, 60978, 61542, 61558, 61672],
#       dtype=int32)

# %%
df_feat[
    (df_feat["customer_id"] == 25734) &
    (df_feat["week"] == 1) &
    (df_feat["product_id"].isin(comprados))
].head()
# Out:
#         customer_id  product_id  week  items  n_orders customer_type  \
# 78970         25734         124     1      0         0     abarrotes
# 236910        25734        1304     1      0         0     abarrotes
# 315880        25734        1370     1      4         1     abarrotes
# 394850        25734        1372     1      0         0     abarrotes
# 552790        25734       10652     1      0         0     abarrotes
#
#                Y           X  num_deliver_per_week  num_visit_per_week  ...  \
# 78970  -46.45126 -107.099792                     4                   1  ...
# 236910 -46.45126 -107.099792                     4                   1  ...
# 315880 -46.45126 -107.099792                     4                   1  ...
# 394850 -46.45126 -107.099792                     4                   1  ...
# 552790 -46.45126 -107.099792                     4                   1  ...
#
#        sub_category segment  package  size compra  items_prev  compra_prev  \
# ...

# %%
#Ahora que generamos las nuevas variables, volvemos a generar el holdout, para así incorporarlas rapidamente.
train_full = df_feat[df_feat["week"].isin(train_weeks)].copy()
val_full   = df_feat[df_feat["week"].isin(val_weeks)].copy()
test_full  = df_feat[df_feat["week"].isin(test_weeks)].copy()

# %% [markdown]
# Finalmente, se decide no usar IQR, ya que hay muchas variables como recencia, que tienen datos muy dispersos, que se eliminan totalmente al usar esto. Creemos que es preferible ver como funcionan en el modelo y en iteraciones posteriores usar algún tipo de reducción de ruido.  De hecho, por ejemplo en el cálculo de regresión logística, el modelo pasa de 0.24 a 0.38 De F1 en 1 por tan solo dejar de usar IQR.[texto del enlace]

# %%
y_col   = "compra"

categorical_columns = ["customer_type", "brand", "sub_category", "segment", "package"]
#Por ahora, como solo vamos a evaluar los modelos, podemos eliminar todas las id. en iteraciones posteriores será necesario guardarlas para comparar y sacar top N.
drop_cols = ["customer_id","product_id","num_visit_per_week", "category", "n_orders", "items","compra","week"]
numeric_columns = ["num_deliver_per_week", "items_prev", "recencia_producto", "popularity_prev","frec_producto","size","X","Y"]

#Agregamos imputer a categoricas para hacer más robusto el pipeline, sin embargo en este caso no hay nulos en las categoricas.
categoric_transformations = Pipeline([
    ("imputer", SimpleImputer(strategy="most_frequent")),
    ("onehot", OneHotEncoder(handle_unknown="ignore", min_frequency=20, dtype=np.float32, sparse_output=True))
])

numeric_transformations = Pipeline([
    ("imputer", SimpleImputer(strategy="median")),
    ("scale",   StandardScaler())
])

preprocessor = ColumnTransformer(
    transformers=[
        ("num", numeric_transformations, numeric_columns),
        ("cat", categoric_transformations, categorical_columns),
        ("drop", "drop", drop_cols),
    ],
    remainder="passthrough",
    verbose_feature_names_out=False
)



X_train = preprocessor.fit_transform(train_full)
X_val   = preprocessor.transform(val_full)
X_test  = preprocessor.transform(test_full)

feature_names = preprocessor.get_feature_names_out()

y_train = train_full[y_col].astype("int8").to_numpy()
y_val   = val_full[y_col].astype("int8").to_numpy()
y_test  = test_full[y_col].astype("int8").to_numpy()

# %%
#Reconstruimos df_featp para revisar correlaciones y detalles previo a realizar el modelo.
df_featp = pd.DataFrame(X_train, columns=feature_names)
df_featp[y_col] = y_train

# %% [markdown]
# hora que tenemos todas las variables de interes, podemos hacer mapas de calor con correlación, para saber de manera sencilla que tanto podrían explicar de la compra.

# %%
corr = df_featp.corr()

plt.figure(figsize=(14, 10))
sns.heatmap(
    corr,
    cmap="coolwarm",
    center=0,
    vmin=-0.05,
    vmax=0.05,
    annot=True,
    fmt=".2f",
    annot_kws={"size": 5},
    cbar_kws={"shrink": 0.8}
)
plt.title("Mapa de calor")
plt.xticks(rotation=60, ha="right", fontsize=6)
plt.yticks(fontsize=6)
plt.tight_layout()
plt.show()

# %% [markdown]
# De acá destaca mucho la futura importancia que podrían tener  variables como compra_prev, frecuencia del producto, items_prev, popularidad previa y recencia del producto. Al tener correlaciones muy marcadas versus la variable objetivo.

# %% [markdown]
# ## 📌 Baseline [0.25 puntos]
#
# <center>
# <img src="https://media1.giphy.com/media/v1.Y2lkPTc5MGI3NjExN3lzeGFqZmU3NzJrZHllNjRmaHVzczJpZ29rdHdlMzVpZnQwNXo1diZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/qAtZM2gvjWhPjmclZE/giphy.gif" width="300" height="200">
#
# En esta sección se debe construir el modelo más sencillo posible que pueda resolver el problema planteado, conocido como **Modelo baseline**. Su propósito es servir como referencia para comparar el rendimiento de los modelos más avanzados desarrollados en etapas posteriores.
#
# Pasos requeridos:
# - Implemente, entrene y evalúe un modelo básico utilizando un pipeline.
# - Asegúrese de incluir en el pipeline las transformaciones del preprocesamiento realizadas previamente junto con un clasificador básico.
# - Evalúe el modelo y presente el informe de métricas utilizando **`classification_report`**.
#
# Documente claramente cómo se creó el modelo, las decisiones tomadas y los resultados obtenidos. Este modelo será la base comparativa en las secciones posteriores.

# %% [markdown]
# En este caso usamos DummyClassifier como baseline, centrado en predecir la clase 1, para saber con que probabilidad el azar podría predecir una buena compra.

# %%
dummy = DummyClassifier(strategy="constant", constant=1, random_state=19)

dummy.fit(X_train, y_train)
y_pred_dummy = dummy.predict(X_val)

print(classification_report(y_val, y_pred_dummy, digits=3,zero_division=0))
# Out:
#               precision    recall  f1-score   support
#
#            0      0.000     0.000     0.000   1323660
#            1      0.026     1.000     0.051     35220
#
#     accuracy                          0.026   1358880
#    macro avg      0.013     0.500     0.025   1358880
# weighted avg      0.001     0.026     0.001   1358880

# %% [markdown]
# Es lógico que el recall sea 1, ya que siempre que la compra es positiva, predice positivo. Pero el f1-score es la métrica a superar si es que el modelo está efectivamente aprendiendo, en este caso, el azar obtiene un F1 de 0.051 para la clase 1. Más adelante se explica porque consideramos este valor como la mejor métrica de comparación.

# %% [markdown]
# Un modelo básico que se puede usar para verificar si aprende, es Regresión Logística.

# %%
t1=time.time()
clf = LogisticRegression(max_iter=500, random_state=19, n_jobs=-1)


clf.fit(X_train, y_train)

y_pred = clf.predict(X_val)
t2=time.time()
print(t2-t1, "Tiempo en entrenamiento")
print(classification_report(y_val, y_pred))
# Out:
# 54.92742872238159 Tiempo en entrenamiento
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99   1323660
#            1       0.68      0.26      0.38     35220
#
#     accuracy                           0.98   1358880
#    macro avg       0.83      0.63      0.68   1358880
# weighted avg       0.97      0.98      0.97   1358880

# %%
#Con esto eliminamos todos los datasets utilizados anteriormente menos "weekly_full",  el cual podemos llamar el dataset final con todas las features relevantes.
#tampoco borramos los datos de holdout.
#Lo usamos para cuando estamos muy al borde de la ram, por lo que es recomendable volver a correr esta línea en ese caso.
for var in list(globals().keys()):
    if isinstance(globals()[var], pd.DataFrame) and "full" not in var:
        del globals()[var]


gc.collect()
# Out:
# 74

# %% [markdown]
# ## 📌 Elección de modelo [0.75 puntos]
#
# En esta sección deben escoger un modelo que se adapte a las necesidades del negocio. Para esto, pruebe al menos 3 modelos y desarrolle los siguientes aspectos para cada uno:
#
# - **Estructura y diferencias entre los modelos**: Explicar brevemente cada uno y sus hipérparámetros de mayor importancia.
# - **Clasificadores recomendados**:
#   - `LogisticRegression`
#   - `KNeighborsClassifier`
#   - `DecisionTreeClassifier`
#   - `SVC`
#   - `RandomForestClassifier`
#   - `LightGBMClassifier` (del paquete `lightgbm`)
#   - `XGBClassifier` (del paquete `xgboost`)
#   - Otro (según lo que se estime adecuado)
#
# - **Evaluación de resultados**: Se utilizará el **`classification_report`** para evaluar el rendimiento de cada modelo, destacando métricas clave como precisión, recall y F1-score. **Importante: No optimicen hiperparámetros, la idea es hacer una selección rápida del modelo.**
#
# **Nota:** Pueden ocupar mas de 1 **instancia** de modelo para resolver el problema (e.g: (modelo_1, grupo_1), (modelo_2, grupo_2), ...).
#
# A continuación, se deben responder las siguientes preguntas para evaluar el rendimiento de los modelos entrenados:
#
# 1. ¿Hay algún clasificador que supere al modelo baseline?
# 2. ¿Cuál es el mejor clasificador entrenado y por qué?
# 3. ¿Qué factores hacen que el mejor clasificador sea superior a los otros?
# 4. En términos de `tiempo de entrenamiento`, ¿Qué modelo considera más adecuado para experimentar con grillas de optimización?

# %%
print("\n===== DecisionTree =====")
t1=time.time()
tree = DecisionTreeClassifier(random_state=19)
tree.fit(X_train, y_train)
y_pred = tree.predict(X_val)
t2=time.time()

print(t2-t1, "Tiempo en entrenamiento")
print(classification_report(y_val, y_pred, digits=3))
# Out:
# ===== DecisionTree =====
# 133.95903539657593 Tiempo en entrenamiento
#               precision    recall  f1-score   support
#
#            0      0.983     0.984     0.983   1323660
#            1      0.362     0.343     0.353     35220
#
#     accuracy                          0.967   1358880
#    macro avg      0.672     0.664     0.668   1358880
# weighted avg      0.966     0.967     0.967   1358880

# %%
print("\n===== RandomForest =====")
t1=time.time()
rf = RandomForestClassifier(n_estimators=50, random_state=19, n_jobs=-1)
rf.fit(X_train, y_train)
y_pred = rf.predict(X_val)
t2=time.time()
print(classification_report(y_val, y_pred, digits=3))
# Out:
# ===== RandomForest =====
#               precision    recall  f1-score   support
#
#            0      0.981     0.996     0.988   1323660
#            1      0.650     0.266     0.378     35220
#
#     accuracy                          0.977   1358880
#    macro avg      0.815     0.631     0.683   1358880
# weighted avg      0.972     0.977     0.973   1358880

# %%
print("\n===== XGBoost =====")
t1 = time.time()

xgb_clf = xgb.XGBClassifier(
    objective="binary:logistic",
    eval_metric="logloss",
    tree_method="gpu_hist",
    predictor="gpu_predictor",
    device="cuda",
    n_estimators=200,
    learning_rate=0.1,
    max_depth=6,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=19
)


xgb_clf.fit(X_train, y_train)
y_pred = xgb_clf.predict(X_val)

t2=time.time()

print(t2-t1, "Tiempo en entrenamiento")

print(classification_report(y_val, y_pred, digits=3))
# Out:
# ===== XGBoost =====
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:183: UserWarning: [22:09:46] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:183: UserWarning: [22:09:46] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "predictor" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /usr/local/lib/python3.12/dist-packages/xgboost/core.py:2676: UserWarning: [22:09:57] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   if len(data.shape) != 1 and self.num_features() != data.shape[1]:
# ...

# %%
print("\n===== KNN =====")
t1=time.time()


knn = KNeighborsClassifier(n_neighbors=5, n_jobs=-1)
knn.fit(X_train[:50000], y_train[:50000])   # subset reducido
y_pred = knn.predict(X_val[:50000])
t2=time.time()
print(t2-t1, "Tiempo en entrenamiento")
print(classification_report(y_val[:50000], y_pred, digits=3))
# Out:
# ===== KNN =====
# 19.781129837036133 Tiempo en entrenamiento
#               precision    recall  f1-score   support
#
#            0      0.982     0.992     0.987     48807
#            1      0.446     0.275     0.340      1193
#
#     accuracy                          0.975     50000
#    macro avg      0.714     0.633     0.664     50000
# weighted avg      0.970     0.975     0.972     50000

# %% [markdown]
# Cabe recalcar que acá se usan solo 50000 datos, puesto que hacerlo correr con todos es muy costos.

# %%
print("\n===== LightGBM =====")
t1=time.time()
lgbm_clf = lgb.LGBMClassifier(
    objective="binary",
    boosting_type="gbdt",
    n_estimators=200,
    learning_rate=0.1,
    max_depth=-1,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=19,
    device="gpu"
)

lgbm_clf.fit(X_train, y_train)
y_pred = lgbm_clf.predict(X_val)
t2=time.time()
print(t2-t1, "Tiempo en entrenamiento")
print(classification_report(y_val, y_pred, digits=3))
# Out:
# ===== LightGBM =====
# [LightGBM] [Info] Number of positive: 132598, number of negative: 6152222
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1153
# [LightGBM] [Info] Number of data points in the train set: 6284820, number of used features: 46
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 7 dense feature groups (47.95 MB) transferred to GPU in 0.100360 secs. 1 sparse feature groups
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.021098 -> initscore=-3.837247
# [LightGBM] [Info] Start training from score -3.837247
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# ...

# %%
print("\n===== RandomForest (GPU) =====")

rf_gpu = cuRF(
    n_estimators=100,
    max_depth=16,
    random_state=19,
    n_streams=8
)

t0 = time.time()
rf_gpu.fit(X_train, y_train)
print(f"Entrenamiento en {time.time()-t0:.1f} segundos")


y_pred = rf_gpu.predict(X_val)
if isinstance(y_pred, cp.ndarray):
    y_pred = y_pred.get()

# 4. métricas
print(classification_report(y_val, y_pred, digits=3))
# Out:
# ===== RandomForest (GPU) =====
# Entrenamiento en 71.0 segundos
#               precision    recall  f1-score   support
#
#            0      0.979     0.999     0.989   1323660
#            1      0.788     0.195     0.313     35220
#
#     accuracy                          0.978   1358880
#    macro avg      0.883     0.597     0.651   1358880
# weighted avg      0.974     0.978     0.971   1358880

# %%
print("\n===== SVC =====")
svc = SVC(random_state=19)

# subset chico
n = 50000
t0 = time.time()
svc.fit(X_train[:n], y_train[:n])

y_pred = svc.predict(X_val[:n])
print(classification_report(y_val[:n], y_pred, digits=3))
# Out:
# ===== SVC =====
#               precision    recall  f1-score   support
#
#            0      0.980     0.998     0.989     48807
#            1      0.703     0.180     0.287      1193
#
#     accuracy                          0.979     50000
#    macro avg      0.841     0.589     0.638     50000
# weighted avg      0.974     0.979     0.972     50000

# %% [markdown]
# Acá ocurre lo mismo que en KNN, y también se usan solamente 50000 datos.

# %% [markdown]
# La clase negativa no es relevante para la predicción, ya que además der ser la clase ampliamente mayoritaria. Sólo se buscan predecir las compras efectivas en las futuras semanas. Así, El f1-score muestra un balance entre la precision (Cuantos aciertos tengo dentro de mi predicción) y el recall (Cuantos valores positivos reales estoy efectivamente prediciendo). Por lo mismo, es esta métrica la que vamos a considerar como la más relevante para medir el rendimiento del modelo y el factor clave para elegir nuestro mejor modelo.
#
# Así,si hacemos un ranking de los mejores modelos por lo antes mencionado,tenemos:
#
# 1. Regresión Logística. 0.38
# 2. Random Forest (CPU) 0.378
# 3. Decission Tree. 0.36
# 4. Xgboost 0.353
# 5. KNN (Subset) 0.34
# 6. LigthGbm 0.328
# 7. Random Forest (GPU) 0.313
# 8. SVC (Subset) 0.27
# 9. Dummy Classifier 0.05 (Modelo Baseline)

# %% [markdown]
# Considerando lo visto anteriormente, todos los modelos  que se probaron, superan al baseline. Es demasiado sorprendente el buen rendimiento de Regresión Logística, pero también esto habla de que los datos como tal tienen bastante información explotable y por lo mismo, modelos superiores no estan teniendo buenos rendimientos dados los hiperparámetros actuales.
#
# Dentro de estos el que obtiene mejores resultados es Random Forest, con un F1-score de la clase positiva de 0.378, seguido de Decission Tree y  XGboost con 0.363 en esta misma métrica. Sin embargo, se opta por seguir con el modelo de XGBoost, ya que RandomForest se demora más de 9 minutos en correr, mientras que XGboost solo toma cerca de 30 segundos. Así, pese a que random forest tiene un rendimiento algo superior a XGBoost, consideramos finalmente a este último como el modelo más completo. Contemplando la posibilidad que este tiene de escalar sus resultados versus regresión Logística.

# %% [markdown]
# ## 📌 Optimización de Hiperparámetros [1.0 puntos]
#
# <center>
# <img src="https://media1.giphy.com/media/v1.Y2lkPTc5MGI3NjExcXJkNzdhYjlneHplaGpsbnVkdzh5dnY3Y2VyaTIzamszdGR1czJ2diZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/2rqEdFfkMzXmo/giphy.gif" width="300" height="200">
#
# A partir de su análisis anterior, se debe proceder a optimizar el rendimiento del modelo seleccionado mediante la optimización de sus hiperparámetros. Para ello, se espera que implementen `Optuna` para optimizar no solo los hiperparámetros del modelo, sino también los de los preprocesadores utilizados (por ejemplo, OneHot Encoding, Scalers, etc.).
#
# Al desarrollar este proceso, deberán responder las siguientes preguntas clave como mínimo:
#
# - ¿Qué métrica decidieron optimizar y por qué?
#
# - ¿Qué hiperparámetro tuvo un mayor impacto en el rendimiento de su modelo?
#
# - ¿Cuánto mejoró el rendimiento del modelo después de la optimización de hiperparámetros?

# %%
# !pip install optuna-integration[xgboost]
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 5.6 MB/s eta 0:00:00
# ...

# %%
import optuna
import xgboost as xgb
import numpy as np
from sklearn.metrics import f1_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

optuna.logging.set_verbosity(optuna.logging.WARNING)

pre_baseline = preprocessor
Xtr_b = pre_baseline.fit_transform(train_full)
Xvl_b = pre_baseline.transform(val_full)

base_clf = xgb.XGBClassifier(
    objective="binary:logistic",
    eval_metric="aucpr",
    device="cuda",
    n_estimators=200,
    learning_rate=0.1,
    max_depth=6,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=19
)
base_clf.fit(Xtr_b, y_train, eval_set=[(Xvl_b, y_val)])
p_base = base_clf.predict_proba(Xvl_b)[:, 1]
f1_base = f1_score(y_val, (p_base >= 0.5).astype("int8"))

pos_weight = (len(y_train) - y_train.sum()) / max(1, y_train.sum())

def build_preprocessor(trial):
    ohe_min_freq = trial.suggest_categorical("ohe_min_freq", [None, 0.01, 0.03, 0.05])
    ohe = OneHotEncoder(
        handle_unknown="ignore",
        min_frequency=ohe_min_freq,
        dtype=np.float32,
        sparse_output=True
    )
    cat_pipe = Pipeline([
        ("imp", SimpleImputer(strategy="most_frequent")),
        ("ohe", ohe)
    ])
    return ColumnTransformer([
        ("num", numeric_transformations, numeric_columns),
        ("cat", cat_pipe, categorical_columns),
        ("drop", "drop", drop_cols)
    ], remainder="drop", verbose_feature_names_out=False)

def objective(trial):
    pre = build_preprocessor(trial)

    Xtr = pre.fit_transform(train_full)
    Xvl = pre.transform(val_full)

    clf = xgb.XGBClassifier(
        objective="binary:logistic",
        eval_metric="aucpr",
        device="cuda",
        learning_rate=trial.suggest_float("learning_rate", 0.02, 0.15, log=True),
        max_depth=trial.suggest_int("max_depth", 4, 7),
        min_child_weight=trial.suggest_int("min_child_weight", 1, 5),
        subsample=trial.suggest_float("subsample", 0.7, 0.95),
        colsample_bytree=trial.suggest_float("colsample_bytree", 0.7, 0.95),
        gamma=trial.suggest_float("gamma", 0.0, 0.5),
        reg_alpha=trial.suggest_float("reg_alpha", 0.0, 0.5),
        reg_lambda=trial.suggest_float("reg_lambda", 0.5, 1.5),
        scale_pos_weight=trial.suggest_float(
            "scale_pos_weight",
            float(pos_weight) * 0.85,
            float(pos_weight) * 1.15
        ),
        n_estimators=trial.suggest_int("n_estimators", 150, 350),
        max_bin=256,
        random_state=19,
        early_stopping_rounds=30
    )

    clf.fit(Xtr, y_train, eval_set=[(Xvl, y_val)])

    p = clf.predict_proba(Xvl)[:, 1]

    thr = np.array([0.3, 0.4, 0.5, 0.6, 0.7])
    f1s = [f1_score(y_val, (p >= t).astype("int8")) for t in thr]
    i = int(np.argmax(f1s))
    f1 = float(f1s[i])

    trial.set_user_attr("preprocessor", pre)
    trial.set_user_attr("model", clf)
    trial.set_user_attr("val_f1", f1)
    trial.set_user_attr("best_threshold", float(thr[i]))

    return f1

study = optuna.create_study(
    direction="maximize",
    sampler=optuna.samplers.TPESampler(seed=19, n_startup_trials=5)
)

study.optimize(
    objective,
    timeout=1200,
    show_progress_bar=True,
    n_jobs=1
)

best = study.best_trial
best_pre = best.user_attrs["preprocessor"]
best_model = best.user_attrs["model"]
best_thr = best.user_attrs.get("best_threshold", 0.5)
# Out:
# [0]	validation_0-aucpr:0.47245
# [1]	validation_0-aucpr:0.50212
# [2]	validation_0-aucpr:0.50465
# [3]	validation_0-aucpr:0.51211
# [4]	validation_0-aucpr:0.52138
# [5]	validation_0-aucpr:0.52740
# [6]	validation_0-aucpr:0.53215
# [7]	validation_0-aucpr:0.53569
# [8]	validation_0-aucpr:0.53730
# [9]	validation_0-aucpr:0.54024
# [10]	validation_0-aucpr:0.54260
# [11]	validation_0-aucpr:0.54454
# [12]	validation_0-aucpr:0.54637
# [13]	validation_0-aucpr:0.54766
# [14]	validation_0-aucpr:0.54906
# [15]	validation_0-aucpr:0.55036
# [16]	validation_0-aucpr:0.55114
# [17]	validation_0-aucpr:0.55149
# [18]	validation_0-aucpr:0.55168
# [19]	validation_0-aucpr:0.55276
# [20]	validation_0-aucpr:0.55325
# [21]	validation_0-aucpr:0.55402
# [22]	validation_0-aucpr:0.55430
# [23]	validation_0-aucpr:0.55505
# [24]	validation_0-aucpr:0.55540
# [25]	validation_0-aucpr:0.55620
# [26]	validation_0-aucpr:0.55709
# [27]	validation_0-aucpr:0.55741
# [28]	validation_0-aucpr:0.55781
# ...

# %%
from sklearn.metrics import f1_score, classification_report, confusion_matrix

X_test_transformed = best_pre.transform(test_full)
y_pred_proba = best_model.predict_proba(X_test_transformed)[:, 1]
y_pred = (y_pred_proba >= best_thr).astype(int)

f1_test = f1_score(y_test, y_pred)
print(f"F1 en test: {f1_test:.4f}")
print(f"Threshold usado: {best_thr}")
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# F1 en test: 0.5412
# Threshold usado: 0.7
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.98   1320267
#            1       0.47      0.64      0.54     38613
#
#     accuracy                           0.97   1358880
#    macro avg       0.73      0.81      0.76   1358880
# weighted avg       0.97      0.97      0.97   1358880

# %%
import joblib
joblib.dump(best_model, "modelo_xgb_final.joblib")
joblib.dump(best_pre, "preprocesador_xgb_final.joblib")
joblib.dump(best_thr, "threshold_xgb_final.joblib")
# Out:
# Modelo, preprocesador y threshold guardados correctamente.

# %% [markdown]
# Guardamos para poder volver a cargar el mejor modelo.

# %%
best_model = joblib.load("modelo_xgb_final.joblib")
best_pre   = joblib.load("preprocesador_xgb_final.joblib")
best_thr   = joblib.load("threshold_xgb_final.joblib")

# %% [markdown]
# Tras la optimización de hiperparámetros, se observa que el mejor ocurre en la iteración 21. El cambio es demasiado considerable, al pasar de 0.35 inicial a 0.54 de F1 score en la clase 1 en el mejor modelo posible. lo que es una mejora relativa del 54%.

# %%
from optuna.importance import get_param_importances

importances = get_param_importances(study)
for k, v in importances.items():
    print(f"{k}: {v:.3f}")
# Out:
# scale_pos_weight: 0.200
# reg_lambda: 0.185
# colsample_bytree: 0.179
# learning_rate: 0.144
# gamma: 0.101
# n_estimators: 0.081
# reg_alpha: 0.057
# ohe_min_freq: 0.036
# subsample: 0.012
# min_child_weight: 0.003
# max_depth: 0.003

# %% [markdown]
# Se busca maximizar el F1 de la clase 1. Dado que este muestra que tan bien estamos prediciendo la compra de un producto en semanas posteriores.
#
#
# Las importancias muestran que los hiperparámetros más relevantes de cambiar fueron: scale_pos_weight (0.200), reg_lambda (0.185) y colsample_bytree (0.179).
#
# El parámetro scale_pos_weight tiene mucho sentido dado que el problema aborda una clase muy minoritaria (predicción de compra), por lo que ajustar este peso mejora el equilibrio entre clases.
#
# En segundo lugar, reg_lambda, asociado a la regularización L2, reduce el sobreajuste de la predicción.
#
# Por su parte, colsample_bytree ayuda al generalizar a hacer que entre los árboles al muestrear subconjuntos de características en cada iteración, estos sean más diversos..
#
#  mientras que el learning_rate (0.144) y gamma (0.101) tambien tuvieron influencia en el rendimiento de xgboost.

# %% [markdown]
# ## 📌 Interpretabilidad [1.0 puntos]
#
# En esta sección, deben explicar el funcionamiento de su modelo utilizando las técnicas de interpretabilidad vistas en clase, como `SHAP`. Se espera que sean capaces de descomponer las predicciones y evaluar la importancia de los atributos y las interacciones entre ellos, con el fin de obtener una comprensión más profunda de cómo el modelo toma decisiones.
#
# Al desarrollar esta parte, deberán responder las siguientes preguntas clave como mínimo:
#
# - ¿Podría explicar el funcionamiento de su modelo para una predicción en particular? Si es así, proporcione al menos tres ejemplos específicos, describiendo cómo el modelo llegó a sus decisiones y qué factores fueron más relevantes en cada caso.
#
# - ¿Qué atributo tiene una mayor importancia en la salida de su modelo? Analice si esto tiene sentido con el problema planteado y justifique la relevancia de dicho atributo en el contexto de las predicciones que se realizan.
#
# - ¿Existe alguna interacción entre atributos que sea relevante para el modelo? Investigue si la combinación de ciertos atributos tiene un impacto significativo en las predicciones y explíquela en **detalle**.
#
# - ¿Podría existir sesgo hacia algún atributo en particular? Reflexione sobre la posibilidad de que el modelo esté favoreciendo ciertos atributos. Si es así, ¿cuál podría ser la causa y qué impacto podría tener esto en la predicción?

# %%
from scipy import sparse
import shap
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split


plt.close('all')

feature_names = best_pre.get_feature_names_out()
X_val_transformed = best_pre.transform(val_full)

explainer = shap.TreeExplainer(best_model, model_output="raw")

def to_dense(X):
    return X.toarray() if sparse.issparse(X) else X

_, sample_idx = train_test_split(
    np.arange(len(y_val)),
    test_size=min(500, len(y_val)),
    stratify=y_val,
    random_state=19
)

X_val_sample_sparse = X_val_transformed[sample_idx]
X_val_sample = to_dense(X_val_sample_sparse)
y_val_sample = y_val.iloc[sample_idx].values if hasattr(y_val, 'iloc') else y_val[sample_idx]


shap_vals = explainer.shap_values(X_val_sample)

ev = explainer.expected_value
if not np.isscalar(ev):

    ev = np.array(ev).ravel()[-1]


shap.summary_plot(
    shap_vals,
    X_val_sample,
    feature_names=feature_names,
    plot_type="bar",
    max_display=20,
    show=False
)
plt.xlabel("mean(|SHAP value|)", fontsize=12)
plt.tight_layout(); plt.show(); plt.close()

shap.summary_plot(
    shap_vals,
    X_val_sample,
    feature_names=feature_names,
    max_display=20,
    show=False
)
plt.tight_layout(); plt.show(); plt.close()


def waterfall_for(idx, title=None):
    shap.waterfall_plot(
        shap.Explanation(
            values=shap_vals[idx],
            base_values=ev,
            data=X_val_sample[idx],
            feature_names=feature_names
        ),
        show=False
    )
    if title:
        plt.title(title)
    plt.tight_layout(); plt.show(); plt.close()


pos_indices = np.where(y_val_sample == 1)[0]
if len(pos_indices) > 0:
    idx_pos = int(pos_indices[0])
    waterfall_for(idx_pos, "Ejemplo positivo (y=1)")


neg_indices = np.where(y_val_sample == 0)[0]
if len(neg_indices) > 0:
    idx_neg = int(neg_indices[0])
    waterfall_for(idx_neg, "Ejemplo negativo (y=0)")


thr = best_thr if 'best_thr' in globals() else 0.5
proba_sample = best_model.predict_proba(X_val_sample_sparse)[:, 1]
idx_near = int(np.argmin(np.abs(proba_sample - thr)))
waterfall_for(idx_near, f"Ejemplo cerca del umbral (p≈{proba_sample[idx_near]:.3f}, thr={thr:.3f})")


p_pos = float(proba_sample[idx_pos]) if len(pos_indices) > 0 else None
p_neg = float(proba_sample[idx_neg]) if len(neg_indices) > 0 else None
print(f"Prob ejemplo positivo: {p_pos}")
print(f"Prob ejemplo negativo: {p_neg}")
print(f"Prob ejemplo cerca del umbral: {float(proba_sample[idx_near]):.6f} "
      f"(dist={abs(float(proba_sample[idx_near]) - thr):.6f})")


shap.plots.heatmap(
    shap.Explanation(
        values=shap_vals[:50],
        base_values=np.repeat(ev, 50),
        data=X_val_sample[:50],
        feature_names=feature_names
    ),
    max_display=10,
    show=False
)
plt.tight_layout(); plt.show(); plt.close()


mean_abs_shap = np.abs(shap_vals).mean(axis=0)
top_idx = int(np.argmax(mean_abs_shap))
shap.dependence_plot(
    top_idx,
    shap_vals,
    X_val_sample,
    feature_names=feature_names,
    show=False
)
plt.tight_layout(); plt.show(); plt.close()

top_features_idx = np.argsort(mean_abs_shap)[-3:]
if len(top_features_idx) > 1:
    shap.dependence_plot(
        int(top_features_idx[-2]),
        shap_vals,
        X_val_sample,
        feature_names=feature_names,
        show=False
    )
    plt.tight_layout(); plt.show(); plt.close()


top5_idx = np.argsort(mean_abs_shap)[-5:][::-1]
for i, idx in enumerate(top5_idx, 1):
    print(f"{i}. {feature_names[int(idx)]}: {mean_abs_shap[int(idx)]:.4f}")
# Out:
# Prob ejemplo positivo: 0.7161193490028381
# Prob ejemplo negativo: 0.3195318877696991
# Prob ejemplo cerca del umbral: 0.700266 (dist=0.000266)
# 1. recencia_producto: 0.3238
# 2. popularity_prev: 0.1777
# 3. frec_producto: 0.1495
# 4. brand_brand 24: 0.0997
# 5. brand_brand 34: 0.0898

# %% [markdown]
# En una predicción específica, el modelo estimó una probabilidad de compra de aproximadamente 0.93, estaba casi seguro de que era un caso positivo. El factor que más aumentó  la probabilidad fue recencia_producto (+0.45), lo que indica que el cliente compro el producto hace muy poco (es recencia negativa por robust scaler, pero probablemente sea 1 semana). Las variables popularity_prev (+0.21) y frec_producto (+0.16) aportaron de manera positiva,  reflejando que se trata de un producto popular y con amplio historial de compra para el usuario. Esto explica 0.82 de los 0.93 y el resto se explican con otras features como la brand o el customer type.

# %% [markdown]
# El atribuyo que mayor importancia tiene es la recencia del producto, con 0.32 de valor Shap. Esto hace mucho sentido con lo planteado, y se puede ver reflejado en el ejemplo anteriormente visto. En los otros ejemplos, se observa como un producto que no se compra hace mucho, baja fuertemente su probabilidad de volver a ser comprado.

# %% [markdown]
# Existe una interacción  muy fuerte entre recencia y popularidad:
# la popularidad sólo impacta positivamente si el producto fue comprado hace poco.
# Vemos como para valores muy altos de popularidad, mientras la recencia no sea alta, no hay definidos valores positivos.
#
# Además,  en general para las categorías de aguas saborizadas, notamos que la recencia suele tener valores bajos o negativos, sin embargo las clases son en general negativas también.

# %% [markdown]
# Dado la gran importancia que tiene, y el efecto que está generando sobre la mayoria de decisiones. La recencia es una variable que pese a ser muy informativa, puede terminar generando sesgo y focalizar solo todo el modelo en esta variable. La causa es la alta correlación que tiene este con que si se compra anteriormente, se vuelva a comprar rapidamente. Y puede tener el impacto de no considerar variables como el tipo de cliente, zona geografica y centrarse solamente en atributos temporales.

# %% [markdown]
# ## 📌 Resultados y Conclusiones [1.0 puntos]
#
# Para finalizar, se deben explicar los desarrollos y resultados obtenidos a lo largo de todo el proceso, desde la selección de las variables hasta la optimización de hiperparámetros e interpretación. Se espera una reflexión crítica sobre el desempeño de los modelos entrenados y una comparación entre los diferentes enfoques. Además, deberán abordar los siguientes puntos clave:
#
# - **Análisis de métricas**: Comenten sobre las métricas obtenidas en cada etapa del modelo, destacando las más relevantes como precisión, recall, F1-score, etc. ¿Cuáles fueron los modelos más efectivos? ¿Qué diferencias notables encontró entre ellos?
#
# - **Impacto de las decisiones tomadas**: Reflexionen sobre cómo las decisiones relacionadas con el preprocesamiento, selección de atributos y optimización de hiperparámetros influyeron en los resultados finales. ¿Hubo alguna decisión que haya tenido un impacto notable en el rendimiento?
#
# - **Lecciones aprendidas**: Concluyan sobre las lecciones más importantes que aprendieron durante el proceso y cómo estas pueden influir en futuras iteraciones del modelo. ¿Qué se podría mejorar si se repitiera el proceso? Si tuvieran más recursos y tiempo, ¿qué otras técnicas/herramientas habrían utilizado?
#
# >  En cuanto al impacto de las decisiones tomadas, creemos fue muy importante el generar variables temporales como recencia, popularidad y sobre todo el hacer todo en cuanto a la semana anterior. Dado que esto nos evita completamente el data leakage pero nos aporta gran información sobre que ha pasado.
#
# Es importante el haber usado multiindex para generar datos sobre las clases negativas, pero quizá el haber usado los 8 millones de datos fue exagerado sin hacer subset o subsampling lo que llevó en mucho gasto de recursos de RAM y complicó el desarrollo del proyecto.
#
# En cuanto a las métricas, destaca fuertemente que al comparar los modelos de manera inicial, casi todos obtenian métricas muy similares. Donde en general se obtenian precisiones muy altas (llegando a 0.76 en XGboost), lo que muestra que el modelo seleccionaba de manera correcta las clases positivas, pero un recall
# muy bajo. Muy pocas veces elegía la clase como positiva dentro del universo de positivas.
#
# Es muy relevante destacar que previo a la eliminación de IQR, los datos daban muy distintos para cada modelo. Siendo los que mas destacaban Random Forest y Xgboost, por lo que creemos que el haber implementado estas nuevas variables, genera mucha robustez en el set de datos. Lo que permite ampliamente que modelos básicos como Regresión Logística suban tanto su rendimiento, pasando de 0.24 a 0.38.
#
# Posterior a realizar la mejora de hiperparámetros con Optuna. Se balanceo fuertemente recall y precision. De hecho el precision de ahora (0.47) es mucho más bajo al inicial. Se puede decir que el modelo ahora se atreve más a considerar casos positivos, y con esto gana el tener mayor capacidad de captación de compra.
#
# Por lo mismo, creemos que el haber usado F1-score fue justificado, ya que al buscar mejorar esta métrica, buscamos un balance de un modelo que prediga bien y de manera amplia.
#
# En cuanto a las lecciones aprendidas, se nos hizo muy importante el fuerte gasto de RAM al usar multiindex, lo que provocó reiniciar el entorno muchas veces y perder más tiempo del deseado. Pese a que generar todos los datos es clave para en un momento poder generar todas las variables temporales. Provoca mucho gasto de Ram innecesario que dificulta el trabajo. Con mayores recursos y tiempo, se podría haber hecho una busqueda de mejores hiperparametros más amplia, y con modelos que estaban funcionando mejor que Xgboost, como RandomForest.
#
# Por lo mismo, algo que nos hizo avanzar mucho más rapido, fue la implementación de gc.collect().
#
# Mucho éxito!
#
# <center>
# <img src="https://media3.giphy.com/media/v1.Y2lkPTc5MGI3NjExaHpvOTY5Z3hpdHI3aDBpdGRueXRqamZncXp2emFrbjJ5M2s5eTR1dSZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/1PMVNNKVIL8Ig/giphy.gif" width="300" height="200">
