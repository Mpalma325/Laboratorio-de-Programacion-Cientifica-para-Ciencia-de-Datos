# %% [markdown]
# <h1><center>Laboratorio 1: Git 👾</center></h1>
#
# <center><strong>MDS7202: Laboratorio de Programación Científica para Ciencia de Datos - Primavera 2025</strong></center>

# %% [markdown]
# ### Cuerpo Docente:
#
# - Profesores: Diego Cortez, Gabriel Iturra
# - Auxiliares: Melanie Peña, Valentina Rojas
# - Ayudantes: Nicolás Cabello, Cristopher Urbina

# %% [markdown]
# ### Equipo: **SUPER IMPORTANTE - notebooks sin nombre no serán revisados**
#
# - Nombre de alumno 1: Isaac Torrejón
# - Nombre de alumno 2: Marcelo Palma

# %% [markdown]
# ### **Link de repositorio de GitHub:** [Github Laboratorio de Programación](https://github.com/Mpalma325/Laboratorio-de-Programacion-Cientifica-para-Ciencia-de-Datos)

# %% [markdown]
# ## Reglas:
#
# - **Grupos de 2 personas**
# - Fecha de entrega: Entregas Martes a las 23:59.
# - Instrucciones del lab el viernes a las 16:15 en formato online. Asistencia no es obligatoria, pero se recomienda **fuertemente** asistir.
# - <u>Prohibidas las copias</u>. Cualquier intento de copia será debidamente penalizado con el reglamento de la escuela.
# - Tienen que subir el laboratorio a u-cursos y a su repositorio de github. Labs que no estén en u-cursos no serán revisados. Recuerden que el repositorio también tiene nota.
# - Cualquier duda fuera del horario de clases al foro. Mensajes al equipo docente serán respondidos por este medio.
# - Pueden usar cualquier material del curso que estimen conveniente.

# %% [markdown]
# ## Objetivos del lab:
#
#
# - Conocer los elementos básicos que conformar `Git`
# - Clonar repositorios
# - Identificar ramas de un repositorio
# - Reconocer y solucionar problemas entre ramas
# - Subir cambios a un repositorio

# %% [markdown]
# ## Parte 1: Conocimiento Teórico (2.5 pts)
#
# <p align="center">
#   <img src="https://cdn.thedesigninspiration.com/wp-content/uploads/sites/3/2019/04/macintosh-hdusersbrittanyloefflerdownloadsanig-1.gif" width="350">
# </p>

# %% [markdown]
# Responda las siguientes preguntas (0.2 pts c/u):
#
# 1. ¿Qué es `Git` y cómo se relaciona con el control de versiones?
#
# 2. Nombre y explique 3 diferencias entre `Git` y `Github`.
#
# 3. ¿Qué es un `hash` y cómo se representa en un `commit`? De un ejemplo.
#
# 4. ¿Que elementos componen a la estructura de datos de `Git`?
#
# 5. ¿Que comandos de `Git` sirven para crear un repositorio y hacer seguimiento a cambios en los archivos?

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
#
# 1. Git es un DVCS, sistema de control de versiones distribuido, que permite la colaboracion entre múltiples usuarios de manera simultanea. Este, a su vez, permite revertir cambios, comparar versiones y trabajar en ramas paralelas sin afectar el proyecto principal.
#
# 2. Git es un DVCS que funciona localmente. Por otro lado, GitHub es una plataforma en línea (servicio en la nube) para alojar repositorios Git. Cabe destacar que Git funciona como software, mientras que Github funciona como interfaz grafica. Git funciona sin conexión a internet, mientras que GitHub requiere conexión a internet para sincronizar los cambios con el repositorio remoto. Finalmente, git se centra en el control de versiones, mientras que  GitHub ofrece servicios integración continua (CI/CD), Issues (seguimiento de tareas, errores o mejoras), Pull Requests (solicitud de incorporación de cambios a la rama principal) y colaboración en equipo.
#
# 3. Un hash puede apuntar a un blob, un commit o un arbol, en git se utiliza el hash SHA1. Es una cadena unica que identifica cada commit. Cada commit tiene un hash de 40 caracteres,un ejemplo seria `4015b57a143aec515gfd144a017a32137a3fd0f` del commit `4015b5`.
#
# 4. Los elementos que lo componen son:
# - `Blob`: Binary Large Objects. Almacena el contenido de un archivo en un momento dado.
# - `Tree`: Representa un directorio, contiene referencias a blobs y otros trees, organizando la estructura del proyecto.
# - `Commit`: Registra un punto en el historial, contiene un tree, metadatos (autor, fecha, mensaje) y referencias a commits padres.
# - `Tag`: Etiqueta específica que marca un commit, usada para versiones o hitos.
#
#
# 5. Primero tenemos `git init (nombre del repositorio)` que inicializa un nuevo repositorio Git en el directorio actual. Luego `git status` que muestra el estado actual del repositorio, indicando archivos modificados, preparados o sin seguimiento, `git diff` que muestra las diferencias entre los archivos del directorio de trabajo y aquellos listos para ser commiteados, y finalemente `git show` que evidencia detalles de archivos modificados en un commit en específico.

# %% [markdown]
# Responda si las siguientes afirmaciones son Verdaderas (V) o Falsas (F). Justifique en **cualquiera** de los casos (0.2 pts c/u):
#
#
# 6. `Git` siempre resuelve automáticamente los problemas de lineas al hacer merge entre diferentes ramas.
# 7. Ejecutar `git pull` sobre un repositorio es equivalente a ejecutar `git clone`.
# 8. `git status` genera los mismos resultados que `git log`.
# 9. En `Git` es posible deshacer cambios y volver a versiones anteriores del código.
# 10. El comando `git commit` se utiliza para enviar cambios al repositorio remoto.

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
#
# 6. **Falso**. Cuando dos ramas modifican las mismas líneas de un archivo de manera distinta, se produce un conflicto de merge que requiere resolución manual del usuario.
#
# 7. **Falso**. git clone crea una copia local inicial de un repositorio remoto, mientras que git pull obtiene el registro de cambios de un repositorio remoto
#
# 8. **Falso**. git status muestra el estado actual de los archivos en el área de trabajo y el área de preparación (staging), mientras que git log muestra el historial de commits realizados en el repositorio.
#
# 9. **Verdadero**. Comandos como git checkout, git reset o git revert, dan la posibilidad de volver a versiones anteriores del código. Por ejemplo, `git checkout commit-hash folder/file` revierte los cambios y vuelve a un version anterior del archivo
#
# 10. **Falso**. git commit registra los cambios en el repositorio local. Para enviar dichos cambios al repositorio remoto se utiliza git push.

# %% [markdown]
# Por último, investigue y comente con sus palabras para qué sirven los siguientes comandos:
#
# 11. `git stash` (0.25 puntos)
#
# El `git stash` permite guardar avances en el directorio de trabajo pero sin realizarles un `commit`, lo cual es muy útil cuando se realiza un movimiento de una `branch` a otra en un repositorio pero no se desea perder los avances desarrollados en la `branch` de origen.
#
# 12. `git reset`. ¿Cuál es la diferencia de este comando con `git revert`?. (0.25 puntos)
#
# El comando `git reset` sirve para deshacer cambios y devolverse a algún `commit` pasado, pudiendo echar atrás un `commit` y devolverlo a la `staging area`, al directorio de trabajo o eliminarlo de plano. Se diferencia del `git revert` en que este último crea un nuevo `commit` revirtiendo los cambios que se hayan realizado en un `commit` posterior, mientras que reset no crea nada, solo vuelve atrás potencialmente eliminando commits

# %% [markdown]
# ## Parte 2: Creando una presentación personal (1.5 pts)
#
# <p align="center">
#   <img src="https://media.tenor.com/arqlNu8gyJYAAAAC/cat-cat-jumping.gif" width="150">
# </p>

# %% [markdown]
# Para empezar a "*soltar las manos*" con `Git`, se les encomienda crear un repositorio con una presentación personal. El repositorio debe contener un breve resumen de quienes son ustedes, sus gustos, experiencias, y cualquier otro detalle interesante que ustedes consideren relevante.
#
# Para realizar esto, deben seguir los siguientes pasos:
#
# 1. Contar con una cuenta de github (1 por persona)
# 2. Crear un repositorio con su nombre de usuario
# 3. Vincular el repositorio a su ambiente local ¿Qué comando(s) me permiten hacer esto?
# 4. Crear un archivo `readme.md` con la información que ustedes deseen compartir.
# 5. Realizar `push` con los cambios generados
#
#
# **Nota: Deben trabajar todos estos puntos desde su ambiente local**
#
# *Hint: Una buena opción es usar templates de presentación personal que encuentren en Google, como los que ofrece este [sitio](https://durgeshsamariya.github.io/awesome-github-profile-readme-templates/#/)*.
#
# **Entregable:**
#
# Enlace al repositorio con la presentación personal.
#
# IMPORTANTE: DEBEN ADJUNTAR UN ENLACE POR PERSONA

# %% [markdown]
# <code>Link Presentacion 1:</code> [Presentación Marcelo Palma](https://github.com/Mpalma325/Mpalma325)
#
# <code>Link Presentacion 2:</code> [Presentación Isaac Torrejón](https://github.com/isaactorrejon/isaactorrejon/blob/main/isaactorrejon.md)

# %% [markdown]
# ## Parte 3: Trabajando sobre un repositorio externo (2 pts)
#
# <p align="center">
#   <img src="https://media.tenor.com/YXL-0SK15j4AAAAC/dance-animals.gif" width="300">
# </p>
#
# Tras muchos dolores de cabeza, un grupo de entusiastas académicos decidieron aprender sobre `Git` y así trabajar colaborativamente de forma más ordenada y eficiente. Después de una infinidad de intentos y aprender de sus errores "*a la mala*", los académicos lograron levantar un [repositorio](https://github.com/MDS7202/lab1) en `Github`. Usando el repositorio de los académicos, responda las siguientes preguntas (**incluya también los comandos en `Git` ocupados**):

# %% [markdown]
# 1. Clone el repositorio a su ambiente local. (0.25 pts)

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
#
# ```bash
# cd ~/Downloads
# git clone https://github.com/MDS7202/lab1.git
# cd lab1

# %% [markdown]
# 2. Descomprima los archivos subidos con la tarea en U-cursos en la carpeta recién clonada de github. Una vez realizado esto, cree un archivo `.gitignore` con el cual omita la carpeta `videos` y los archivos con la extensión `.txt` exceptuando el archivo `171.txt` de la carpeta `texts`. (0.25 pts)

# %% [markdown]
# <code>Para esta pregunta usted deberá adjuntar el .gitignore creado en su repo.</code>

# %% [markdown]
# ```bash
# unzip ../lab1.zip -d.
# nano .gitignore
# git add .gitignore
# git commit -m "Se omite carpeta videos y .txt excepto 171.txt"

# %% [markdown]
# ```bash
# cat .gitignore
# videos/ #Se ignora carpeta videos
# *.txt #Se ignoran terminaciones .txt
# !texts/171.txt #No se ignora 171.txt

# %% [markdown]
# 3. Inspeccione brevemente el repositorio: ¿Cual es el objetivo del proyecto? Explique brevemente la estructura del proyecto, asi como también cada elemento que lo conforma. (0.25 pts)

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
# La estructura del proyecto parte desde la carpeta Lab1/, donde se encuentran 3 archivos. en el Readme.md, se observa que el objetivo del proyecto es poder emular los sonidos de los animales. Además, el proyecto contiene un animales.py, función que recibe los nombres de los animales y emula su sonido, con un link a la canción What does the fox say en el caso de un zorro, además, el repositorio contiene un main.py, que sirve para llamar a la función animales.

# %% [markdown]
# 4. Identifique los últimos cambios al repositorio, reconociendo las principales ramas de trabajo. ¿Son informativos los `commit` realizados? (0.25 pts)
# *Hint: Se recomienda usar los argumentos `all`, `graph` y `decorate`*

# %% [markdown]
# al usar:
#
# <code>git log --oneline --all --graph --decorate </code>
#
# se obtiene lo siguiente:
#
# -25543a3 (origin/fix-ifs) fix ifs
#
# -362fe21 (origin/new_features, origin/main, origin/HEAD) Se separa el proyecto en modulos
#
# -c8b1a62 se agrega funcion
#
# -b262d86 primer commit
#
# Así, se observa que las tres ramas de trabajo son new_features, fix-ifs y main. Donde los cambios nuevos son 4 según los commit, en general, los commit no son lo suficientemente informativos. primer commmit no indica que está "commiteando", se agrega función no indica que función, la separación en modulos no menciona que modulos, y fix-ifs no menciona que if se está arreglando.

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>

# %% [markdown]
# 5. Uno de los académicos se da cuenta que la rama principal de trabajo no se ejecuta correctamente para todos los argumentos. Señale y explique el error en el código e identifique a la persona que lo cometió usando `git blame` (0.25 pts)
#
# *Hint: Le puede ser útil esta [documentación](https://www.atlassian.com/es/git/tutorials/inspecting-a-repository/git-blame).*

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
#
# En relación al código, el error es que el else se asocia solo a fox. Por lo que en caso de que no diga fox, el else salta si o si. El problema recae en que si se dice gato o perro, animales que están en el código, el código igualmente tras decir miau o guau, dice animal no encontrado ya que efectivamente no es fox.
#
# Al usar <code> git blame -C -C animales.py </code> (se agrega -C -C para saber quien escribió la linea originalmente y no quien fue el último que commiteo. , se obtiene que la persona que cometió el error fue seba el 22 de Marzo de 2023, dentro del commit c8b1a62d

# %% [markdown]
# 6. Busque los siguientes `commit`:
#
# - `c8b1a62d7299552b0654f930d695b33109214111`
# - `362fe21ee44f53ee944cee4ba484600308f83d78`
# - `25543a3baf77292baf849726784ca005473acab1`
#
# ¿Qué diferencias existen entre cada uno? (0.25 pts)

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
#
# el commit 1 es el que corresponde al "se agrega función", antes visto. En este se agrega el error por seba, y la función que hacia referencia el commit es la que recibe un input de animal y  entrega el sonido.
#
# el commit 2 es el que corresponde al "Se separa el proyecto en modulos", en este commit se toma lo que estaba anteriormente main.py y se traspasa a un nuevo modulo llamado animales.py y en main.py se elimina lo anterior y se genera el llamado a la función animales.
#
# el commit 3 es el que corresponde a "fix ifs", este solo se encuentra en la rama fix-ifs y no interactua con los dos commits anteriores, en este se encuentra el arreglo del error antes visto en 5. Sin embargo, la correción no está integrada en  main, por lo cual la rama no recibe la correción y el cambio no es efectivo.

# %% [markdown]
# 7. Realice una `merge` de la rama `fix-ifs` con la rama `main` y describa lo que ocurre. ¿Qué parte del código podría estar ocasionando esto? (0.25 pts)

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
#
# Al hacer el merge se genera un conflicto en main.py debido a que en la rama main la función fue eliminada (para separarla en animales.py), mientras que en fix-ifs la función fue modificada directamente en main.py. Esta diferencia ocasiona el conflicto, donde git arroja:
#
#
# -CONFLICT (content): Merge conflict in main.py
#
# -Automatic merge failed; fix conflicts and then commit the result.

# %% [markdown]
# 8. Cree una rama nueva y proponga una solución al problema anterior, adjuntando el código corregido y señalando las líneas modificadas. (0.25 pts)

# %% [markdown]
# ```bash
# git checkout main
# git checkout -b fix-conflict
# git add animales.py
# nano animales.py

# %% [markdown]
# Primero se crea la rama fix-conflict, posterior a esto se agrega animales.py, y se edita con <code>nano animales.py</code> , acá se edita el archivo original  y de manera manual se edita para llegar a lo que estaba en fix-ifs. (agregar elifs, en vez de ifs).
#
# posteriormente, al usar <code> git diff animales.py </code>,  para observar el código corregido y las lineas modificadas, se obtiene:
#
# ```bash
# diff --git a/animales.py b/animales.py
# index 694e39c..67756c7 100644
# --- a/animales.py
# +++ b/animales.py
# @@ -6,9 +6,9 @@ def animales(input):
#
#      if input.lower() == 'gato':
#          print('miau')
# -    if input.lower() == 'perro':
# +    elif input.lower() == 'perro':
#          print('guau')
# -    if input.lower() == 'fox':
# +    elif input.lower() == 'fox':
#          print('https://www.youtube.com/watch?v=jofNR_WkoCE')
#      else:
#          raise ValueError('animal no reconocido :(')

# %% [markdown]
# Para que los cambios se incorporen a la rama principal, habría que moverse  a la rama principal usando <code>git checkout main</code>,  donde posteriormente hacemos  <code>git merge fix-conflict </code>. Así animales .py se corregiría según lo pedido y main.py seguiría con el funcionamiento de ser un llamado a la función animales. Luego se haría git push para subir los cambios realizados en rama main.

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>

# %% [markdown]
# ## Fin

# %% [markdown]
# Eso ha sido todo por ahora!! Esperamos que este laboratorio les haya gustado y servido para trabajar con `Git`. Recuerden los dias de plazo que tienen disponibles y que ante cualquier duda no duden en contactar al equipo docente.
#
# Nos vemos!!
#
# <p align="center">
#   <img src="https://media.tenor.com/OYLdav9k9LkAAAAd/kitty-cat.gif" width="350">
# </p>
